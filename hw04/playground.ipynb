# %%
import sys
import math

# %%
path_to_input = "./hmm-training-data/ja_gsd_train_tagged.txt"
sents = []
with open(path_to_input, 'r') as reader:
    for line in reader:
        sents.append(line.strip())

# transition prob - pairwise prob of tag
p_transition = {}
transition_count = {}
# emission prob (#word-in-tag / #vocab-in-tag)
# P(observation|state) or P(word|tag) --> This version is better than a more intuitive version
# P(tag|word) ref. Charniak paper
p_emission = {}
tag_count = {}
word_count = {}


# count transition using sliding window
def split_word_tag_token(token):
    if len(token.split('/')) == 2:
        w = token.split('/')[0]
        t = token.split('/')[1]
    else:
        t = token.split('/')[-1]
        w = ''.join(token.split('/')[:-1])
    return w, t


for sent in sents:
    word_tag = sent.split(' ')
    for wt_token in word_tag:
        w, t = split_word_tag_token(wt_token)
        if t not in tag_count.keys():
            tag_count[t] = 0
        tag_count[t] += 1

        if w not in word_count.keys():
            word_count[w] = {}

        if t not in word_count[w].keys():
            word_count[w][t] = 0

        word_count[w][t] += 1

for sent in sents:
    mod_sent = ('#/#Q0 ' + sent + ' #/#QT').split(' ')
    i = 0
    while i < len(mod_sent) - 1:
        _, t1 = split_word_tag_token(mod_sent[i])
        _, t2 = split_word_tag_token(mod_sent[i + 1])

        if t1 not in transition_count.keys():
            transition_count[t1] = {}

        if t2 not in transition_count[t1].keys():
            transition_count[t1][t2] = 0

        transition_count[t1][t2] += 1
        i += 1
        
tag_list = list(tag_count) + ['#Q0', '#QT']
p_transition = dict.fromkeys(tag_list, {})
p_emission = dict.fromkeys(word_count.keys(), {})

for k in tag_list:
    p_transition[k] = dict.fromkeys(tag_list, 0)
    
for w in word_count.keys():
    p_emission[w] = dict.fromkeys(tag_list, 0)

# %%
for t1, next_states in transition_count.items():
    count = 0
    possible_tags = []
    for next_tag, c in next_states.items():
        possible_tags.append(next_tag)
        count += c
        

    for t2 in possible_tags:
        p_transition[t1][t2] = transition_count[t1][t2]
        
    for t2 in p_transition[t1].keys():
        # add one to all transition
        p_transition[t1][t2] += 1
        count += 1
    
    for t2 in p_transition[t1].keys():
        p_transition[t1][t2] /= count

# %%
tag_count_for_word_emission = tag_count.copy() # Number of tag --> aka number of emission by tag
sort_tag_count = sorted(tag_count_for_word_emission.items(), key=lambda kv:kv[1], reverse=True)

# %%
sort_tag_count
# Out:
# [('NN', 32369),
#  ('PS', 18872),
#  ('SYM', 17762),
#  ('VV', 15128),
#  ('AV', 14720),
#  ('NNP', 7814),
#  ('PN', 7202),
#  ('PK', 6403),
#  ('PC', 6108),
#  ('XV', 5625),
#  ('CD', 3874),
#  ('XS', 3350),
#  ('XSC', 3068),
#  ('NB', 2161),
#  ('JN', 2020),
#  ('NR', 1732),
#  ('RB', 1634),
#  ('PQ', 1537),
#  ('JJ', 1436),
#  ('PA', 1063),
#  ('JR', 1057),
#  ('XP', 993),
#  ('NP', 858),
#  ('CC', 746),
#  ('PH', 557),
#  ('PM', 541),
#  ('PNB', 467),
#  ('XPC', 416),
#  ('PE', 257),
#  ('PP', 211),
#  ('XA', 166),
#  ('PF', 147),
#  ('AJ', 59),
#  ('PX', 42),
#  ('UNK', 12),
#  ('UH', 9),
#  ('AJN', 3)]

# %%
# How to deal with unseen word emission ?
# Pick top N tags and then add as unseen
# HMM Constraint: Total Probability of state qi emitting the observation vj must be 1
word_count["##unseen##"] = {}
p_emission['##unseen##'] = dict.fromkeys(tag_list, 0)

pick_top_n = int(len(sort_tag_count)/4)
total_top_n = sum([v for k, v in sort_tag_count[0:pick_top_n]])

for i in range(0, pick_top_n):
    tag, count = sort_tag_count[i]
    distribution = int(pick_top_n * (count / total_top_n))
    word_count['##unseen##'][tag] = distribution
    tag_count_for_word_emission[tag] += distribution
    
for w, poss_tag_count in word_count.items():
    for t, n in poss_tag_count.items():
        p_emission[w][t] = n / tag_count_for_word_emission[t]

# %%
p_emission['##unseen##']
# Out:
# {'NN': 6.178369528281487e-05,
#  'PS': 5.298574683410163e-05,
#  'PK': 0.0,
#  'NNP': 0.0,
#  'PN': 0.0,
#  'VV': 6.609822195782933e-05,
#  'PC': 0.0,
#  'SYM': 5.629679671226707e-05,
#  'NB': 0,
#  'JN': 0,
#  'XV': 0,
#  'JR': 0,
#  'CD': 0,
#  'XSC': 0,
#  'AV': 6.793016778751444e-05,
#  'CC': 0,
#  'XP': 0,
#  'XS': 0,
#  'PH': 0,
#  'NP': 0,
#  'PE': 0,
#  'PA': 0,
#  'XPC': 0,
#  'PP': 0,
#  'XA': 0,
#  'PQ': 0,
#  'NR': 0,
#  'RB': 0,
#  'JJ': 0,
#  'PM': 0,
#  'PNB': 0,
#  'PF': 0,
#  'AJ': 0,
#  'PX': 0,
#  'UH': 0,
#  'UNK': 0,
#  'AJN': 0,
#  '#Q0': 0,
#  '#QT': 0}

# %%
sorted_top_tag_from_q0 = sorted(transition_count['#Q0'].items(), key = lambda kv: kv[1], reverse=True)
sorted_top_tag_from_q0
# Out:
# [('NN', 2722),
#  ('NNP', 1102),
#  ('CD', 577),
#  ('CC', 557),
#  ('JR', 382),
#  ('RB', 361),
#  ('NR', 339),
#  ('NP', 332),
#  ('VV', 173),
#  ('JN', 168),
#  ('SYM', 156),
#  ('XP', 146),
#  ('XPC', 59),
#  ('JJ', 55),
#  ('UH', 3),
#  ('UNK', 1)]

# %%
ntags = sum([v for k,v in tag_count.items()])
l_tags = [(k,v/ntags) for k,v in tag_count.items()]
l_tags
# l_tags = sorted(l_tags,key=lambda x: x[1], reverse=True)
# p_emission['##unseen##'] = {}
# for t,prob in l_tags:
#     p_emission['##unseen##'][t] = prob
# p_emission['##unseen##']
# Out:
# [('SP', 0.04952557613787457),
#  ('FS', 0.04320354758186937),
#  ('S', 0.1991710715566682),
#  ('E', 0.15177578355113236),
#  ('RD', 0.12766150156329817),
#  ('A', 0.06285436872099384),
#  ('FC', 0.004496067299714875),
#  ('RI', 0.015520670678467787),
#  ('VA', 0.021458667700411927),
#  ('VM', 0.006369126763012691),
#  ('V', 0.09622525985529981),
#  ('PR', 0.01043044138265844),
#  ('FB', 0.019694296407131395),
#  ('PI', 0.003438169111546669),
#  ('FF', 0.045982341795311195),
#  ('CC', 0.027349566515348582),
#  ('N', 0.017371992507762148),
#  ('PC', 0.015698194689496014),
#  ('AP', 0.0061626192399798566),
#  ('NO', 0.0035359884645622223),
#  ('B', 0.03152319224401219),
#  ('I', 0.00022462221803571492),
#  ('T', 0.001373093881218322),
#  ('PE', 0.0023440415333727026),
#  ('CS', 0.010263786188631942),
#  ('DI', 0.005441654378865223),
#  ('BN', 0.006619109554052438),
#  ('PD', 0.0027896630304435565),
#  ('DD', 0.003673660146584112),
#  ('DE', 1.449175600230419e-05),
#  ('DQ', 0.0031700716255040414),
#  ('PQ', 0.002981678797474087),
#  ('SW', 0.0007716860071226981),
#  ('PP', 0.00010506523101670537),
#  ('DR', 0.00014129462102246585),
#  ('SYM', 0.0003188186320506922),
#  ('X', 0.00022824515703629097),
#  ('PART', 8.695053601382514e-05),
#  ('Sw', 3.6229390005760473e-06)]

# %%
word_count
# Out:
# {'ホッケー': {'NN': 1},
#  'に': {'PS': 4728, 'XV': 520, 'PX': 30, 'PC': 14},
#  'は': {'PK': 4830},
#  'デンジャラスプレー': {'NNP': 1},
#  'の': {'PN': 7202, 'PM': 540, 'PNB': 426, 'XV': 55, 'PE': 1},
#  '反則': {'NN': 2},
#  'が': {'PS': 3607, 'PC': 648},
#  'ある': {'VV': 455, 'XA': 86, 'AV': 7},
#  'ので': {'PC': 227},
#  '、': {'SYM': 6184},
#  '膝': {'NN': 2},
#  'より': {'PS': 90, 'VV': 17, 'RB': 1},
#  '上': {'NN': 10, 'XS': 44, 'NB': 23, 'XP': 4},
#  'ボール': {'NN': 11},
#  'を': {'PS': 4720},
#  '浮かす': {'VV': 1},
#  'こと': {'NB': 727, 'NN': 31, 'VV': 2},
#  '基本的': {'JN': 15},
#  'なる': {'VV': 169, 'AV': 51, 'XV': 3},
#  'その': {'JR': 337},
#  '例外': {'NN': 6},
#  '一': {'CD': 134, 'XS': 9, 'NN': 3, 'XP': 11},
#  'つ': {'XSC': 96, 'VV': 19},
#  'この': {'JR': 353},
#  'スクープ': {'NN': 1},
#  'である': {'AV': 399},
#  '。': {'SYM': 6929},
#  'また': {'CC': 222, 'RB': 7},
#  '行き': {'VV': 24, 'AV': 5, 'XS': 1},
#  'たい': {'AV': 68, 'VV': 1},
#  'そんな': {'JR': 21},
#  '気持ち': {'NN': 10},
#  'さ': {'VV': 87, 'XV': 988, 'NB': 39, 'AV': 9, 'PE': 3},
#  'せ': {'AV': 117, 'XV': 17, 'VV': 3},
#  'て': {'PC': 4007, 'AV': 3},
#  'くれる': {'AV': 25, 'VV': 1},
#  'お': {'XP': 241, 'AV': 1},
#  '店': {'XS': 97, 'NN': 37, 'XSC': 1},
#  'です': {'AV': 432, 'XV': 49},
#  '手': {'NN': 37, 'XSC': 2, 'XS': 8},
#  '持っ': {'VV': 41},
#  'た': {'AV': 4508},
#  '特殊': {'JN': 7, 'NN': 3},
#  'な': {'XV': 647, 'PE': 20, 'AV': 113, 'VV': 3},
#  '刃物': {'NN': 1},
#  '使っ': {'VV': 43},
#  'アクロバティック': {'JN': 1},
#  '体術': {'NN': 1},
#  'や': {'PH': 536},
#  '揚羽': {'NNP': 1},
#  'と': {'PS': 1489, 'PQ': 1232, 'PC': 453},
#  '薄羽': {'NNP': 1},
#  '同様': {'JN': 20, 'NR': 3, 'NN': 3},
#  'クナイ': {'NN': 1},
#  '忍具': {'NN': 1},
#  '攻撃': {'VV': 12, 'NN': 22},
#  'し': {'XV': 2154, 'VV': 738, 'PC': 36, 'AV': 34},
#  'くる': {'AV': 21, 'VV': 1},
#  '3': {'CD': 238},
#  '年次': {'XSC': 1},
#  'トータルオフェンス': {'NNP': 1},
#  'で': {'PS': 2437, 'XV': 190, 'AV': 218, 'PC': 128, 'VV': 5, 'CC': 8},
#  '2,892': {'CD': 1},
#  'ヤード': {'XSC': 3},
#  '獲得': {'VV': 20, 'NN': 4},
#  'これ': {'NP': 188},
#  '大学': {'NN': 33},
#  '記録': {'NN': 18, 'VV': 23},
#  'なっ': {'VV': 343, 'AV': 98},
#  '葬儀': {'NN': 6},
#  '最中': {'NB': 8},
#  'よ': {'PE': 46},
#  '!': {'SYM': 130},
#  '1998': {'CD': 7},
#  '年度': {'XSC': 14, 'NN': 3},
#  '着手': {'VV': 3, 'NN': 1},
#  '道': {'NN': 5, 'XS': 10, 'XP': 5},
#  '駅': {'NN': 18, 'XS': 58},
#  '遠山郷': {'NNP': 1},
#  '北': {'NNP': 3, 'NN': 19},
#  '側': {'XS': 56, 'NN': 9},
#  'から': {'PS': 857, 'PC': 53},
#  'かぐら': {'NN': 1},
#  '大橋': {'NNP': 1},
#  '南': {'NNP': 17},
#  '詰': {'NN': 1},
#  '現道': {'NN': 1},
#  '交点': {'NN': 1},
#  'まで': {'PA': 263, 'PK': 2},
#  '1.060': {'CD': 1},
#  'km': {'NNP': 19},
#  'のみ': {'PA': 48},
#  '開通': {'VV': 2},
#  '済み': {'AV': 1, 'XS': 3, 'VV': 1},
#  'そして': {'CC': 45},
#  '第': {'XPC': 165},
#  '40': {'CD': 22},
#  '話': {'NN': 51},
#  'カオル': {'NNP': 2},
#  '百子': {'NNP': 1},
#  'も': {'PK': 1489},
#  '失い': {'VV': 3},
#  '完全': {'JN': 19, 'NN': 7},
#  '孤児': {'NN': 1},
#  'ゲン': {'NNP': 3},
#  'とともに': {'PP': 35},
#  '美': {'XP': 2},
#  '山家': {'NN': 2},
#  '身': {'NN': 11},
#  '寄せ': {'VV': 8, 'NN': 1},
#  '連れ添っ': {'VV': 1},
#  '円盤': {'NN': 1},
#  '生物': {'NN': 6},
#  '調査': {'VV': 3, 'NN': 18},
#  'する': {'XV': 908, 'VV': 123, 'AV': 17},
#  'パートナー': {'NN': 1},
#  '一般的': {'JN': 14},
#  '層流': {'NN': 3},
#  '翼': {'NN': 5},
#  '型': {'XS': 49, 'XP': 4, 'XSC': 5, 'NN': 4},
#  '比べ': {'VV': 18, 'NN': 1},
#  '負': {'XP': 1},
#  '圧': {'NN': 2},
#  '中心': {'NN': 51},
#  '前進': {'VV': 2, 'NN': 1},
#  '圧力': {'NN': 6},
#  '勾配': {'NN': 1},
#  'なだらか': {'JN': 1},
#  '一直線': {'NN': 1},
#  '伸びる': {'VV': 1},
#  '電撃': {'NN': 5},
#  '放ち': {'VV': 2},
#  'ダメージ': {'NN': 10},
#  '与える': {'VV': 13},
#  '配属': {'VV': 5},
#  'れ': {'AV': 1276},
#  '最初': {'NN': 34},
#  '1': {'CD': 317},
#  'カ月': {'XSC': 11},
#  'こそ': {'PK': 12},
#  '「': {'SYM': 705, 'NN': 3},
#  '親切': {'JN': 16, 'NN': 2},
#  '先輩': {'NN': 9},
#  '恵まれ': {'VV': 7},
#  'ラッキー': {'JN': 1},
#  'だ': {'XV': 35, 'AV': 243},
#  '」': {'SYM': 700},
#  '思っ': {'VV': 36},
#  'ものの': {'PC': 36},
#  'その後': {'NR': 47},
#  'すぐ': {'JN': 24, 'RB': 6},
#  'ちょっと': {'RB': 11},
#  'おせっかい': {'JN': 1},
#  'か': {'PE': 124, 'PF': 133},
#  '感じる': {'VV': 11},
#  'ように': {'AV': 159},
#  'なり': {'AV': 35, 'VV': 97, 'PH': 2, 'PA': 5},
#  '半年': {'NR': 4, 'NN': 2},
#  '後': {'NR': 91, 'NB': 86, 'XS': 42, 'XP': 4},
#  '少し': {'RB': 25},
#  '邪魔': {'JN': 1, 'NN': 3, 'VV': 1},
#  '思い': {'VV': 89, 'NN': 10},
#  '年': {'XSC': 847, 'NN': 14, 'XP': 5, 'XS': 6, 'XPC': 13},
#  '生産性': {'NN': 1},
#  '阻害': {'NN': 1, 'VV': 1},
#  '要因': {'NN': 9},
#  '確信': {'VV': 3},
#  '至り': {'VV': 1},
#  'まし': {'AV': 398},
#  '統一教会': {'NNP': 10},
#  '導': {'VV': 1},
#  'ける': {'AV': 23},
#  '色々と': {'RB': 4},
#  '面白い': {'JJ': 9},
#  'メニュー': {'NN': 28},
#  '小泉': {'NNP': 1},
#  '内閣': {'NNP': 2, 'NN': 5},
#  '高': {'XP': 9, 'XS': 5, 'NN': 1},
#  '支持率': {'NN': 1},
#  '背景': {'NN': 14},
#  '国政': {'NN': 1},
#  '主導権': {'NN': 2},
#  '握る': {'VV': 4},
#  '与党': {'NN': 1},
#  '自由': {'NN': 9, 'JN': 5},
#  '民主': {'NN': 4},
#  '・': {'SYM': 838},
#  '公明': {'JN': 1},
#  '両党': {'NN': 1},
#  'に対して': {'PS': 82},
#  '政権交代': {'NN': 1},
#  '展望': {'NN': 2},
#  '見': {'VV': 87, 'NN': 2},
#  '出す': {'AV': 5, 'VV': 4},
#  'ため': {'PC': 196, 'NB': 94},
#  '非自民': {'NN': 1},
#  '勢力': {'NN': 7},
#  '結集': {'NN': 1, 'VV': 1},
#  '狙っ': {'VV': 6},
#  'もの': {'NB': 194, 'NN': 23},
#  'であっ': {'AV': 93},
#  '医師': {'NN': 11},
#  '丁寧': {'JN': 24},
#  '診察': {'NN': 10, 'VV': 1},
#  '検査': {'NN': 20},
#  '安心感': {'NN': 3},
#  'もて': {'VV': 1},
#  'ね': {'PE': 47, 'AV': 1},
#  'エンゲージメント': {'NN': 1},
#  '系': {'XS': 34, 'XSC': 8, 'NN': 1},
#  '事例': {'NN': 4},
#  '言え': {'VV': 9},
#  'ば': {'PC': 113, 'NN': 4},
#  ',': {'SYM': 1101},
#  '日本': {'NNP': 112},
#  '再現性': {'NN': 1},
#  '低い': {'JJ': 12},
#  'という': {'PQ': 235},
#  '前提': {'NN': 6},
#  'い': {'VV': 60, 'AV': 735},
#  '方': {'NB': 68, 'XS': 29},
#  'イイ': {'NNP': 5},
#  'かな': {'NN': 3},
#  'ます': {'AV': 553, 'VV': 2},
#  '店舗': {'NN': 23},
#  '見た目': {'NN': 7},
#  '居酒屋': {'NN': 14},
#  '大': {'NN': 3, 'XP': 48, 'XSC': 3},
#  '二': {'CD': 74, 'NN': 8},
#  '階': {'XSC': 22, 'NN': 3},
#  'しか': {'PK': 43},
#  '見え': {'VV': 15},
#  'ない': {'AV': 484, 'JJ': 113},
#  '残念': {'JN': 10, 'NN': 1},
#  '高松': {'NNP': 2},
#  '展開': {'VV': 22, 'NN': 8},
#  '四国': {'NNP': 2},
#  'スイーツ': {'NN': 2},
#  '専門店': {'NN': 1},
#  'ラ': {'NNP': 4},
#  'ファミーユ': {'NNP': 1},
#  'バレンタイン': {'NNP': 2},
#  '前': {'NR': 43, 'XS': 22, 'NB': 20, 'XP': 15},
#  '焼か': {'VV': 2},
#  'チョコレートケーキ': {'NN': 1},
#  '半熟': {'NN': 1},
#  'ザッハトルテ': {'NNP': 1},
#  '発売': {'NN': 13, 'VV': 29},
#  '開始': {'VV': 20, 'NN': 15},
#  '王子': {'NN': 8},
#  '隠れ家': {'NN': 3},
#  '的な': {'JN': 24},
#  '美容室': {'NN': 19},
#  'いる': {'AV': 1089, 'VV': 41},
#  '思い切っ': {'VV': 1},
#  '口コミ': {'VV': 1, 'NN': 1},
#  'ちゃい': {'AV': 8},
#  'クロヴィス': {'NNP': 1},
#  '2世': {'NN': 13},
#  'バルティルド': {'NNP': 1},
#  '子供': {'NN': 39},
#  'チーム': {'NN': 53},
#  '名': {'XS': 14, 'NN': 23, 'XSC': 18, 'XP': 4},
#  'アマチュア': {'NN': 2},
#  '時代': {'NN': 52},
#  'ロッテ': {'NNP': 2},
#  'ジャイアンツ': {'NN': 2},
#  'まま': {'NB': 36},
#  '維持': {'VV': 7, 'NN': 1},
#  '重光': {'NNP': 2},
#  'オーナー': {'NN': 7},
#  '故郷': {'NN': 10},
#  '釜山': {'NNP': 4},
#  '慶尚南道': {'NNP': 2},
#  '地域': {'NN': 53},
#  'フランチャイズ': {'NN': 1},
#  '保護地域': {'NN': 2},
#  '本拠地': {'NN': 5},
#  'プロ': {'NN': 14},
#  '球団': {'NN': 4},
#  '転向': {'VV': 1},
#  'カット': {'NN': 6, 'VV': 1},
#  '24': {'CD': 32},
#  '時': {'XSC': 43, 'NB': 45, 'XS': 46, 'NN': 10},
#  '受け付け': {'VV': 2},
#  '仕事': {'NN': 27, 'VV': 1},
#  '帰り': {'NN': 8, 'VV': 2},
#  '遅く': {'JJ': 5},
#  'け': {'AV': 25},
#  'なお': {'CC': 35, 'RB': 11, 'NNP': 1},
#  '唯一': {'NN': 19},
#  '趣味': {'NN': 6},
#  '料理': {'NN': 34, 'VV': 2},
#  'であり': {'AV': 93},
#  '腕': {'NN': 9},
#  'ネリン': {'NNP': 1},
#  '上手い': {'JJ': 2},
#  '日向': {'NN': 2},
#  '国': {'XS': 11, 'NN': 19, 'XSC': 3},
#  '高鍋': {'NNP': 1},
#  '藩': {'NN': 12},
#  '7': {'CD': 60},
#  '代': {'XSC': 22, 'XS': 9, 'NN': 2},
#  '藩主': {'NN': 4},
#  '短い': {'JJ': 8},
#  '履帯': {'NN': 1},
#  '長': {'XS': 20, 'XP': 9, 'NN': 1},
#  '長い': {'JJ': 11},
#  '車体': {'NN': 8},
#  '超塹性能': {'NN': 1},
#  '先端': {'NN': 7},
#  '部': {'XS': 41, 'XSC': 13, 'NN': 2, 'XP': 1},
#  'へ': {'PS': 216, 'VV': 3},
#  '75': {'CD': 4},
#  'mm': {'NNP': 9},
#  '砲': {'NN': 4, 'XS': 3},
#  '収納': {'VV': 5},
#  'オーバーハング': {'NN': 1},
#  'ほんの': {'JR': 4},
#  '段差': {'NN': 1},
#  '乗り越え': {'VV': 2},
#  'だけ': {'PA': 113},
#  'つかえる': {'VV': 1},
#  '多く': {'JJ': 42, 'NR': 55},
#  '不整地': {'NN': 1},
#  '走破': {'NN': 1},
#  '性': {'XS': 25, 'NN': 4},
#  '劣悪': {'JN': 1},
#  'あっ': {'XA': 17, 'VV': 104, 'AV': 4},
#  'やっぱり': {'RB': 5},
#  'せっかく': {'RB': 2},
#  '来': {'VV': 27, 'AV': 4, 'XP': 1, 'XS': 1},
#  '何': {'CD': 13, 'NN': 7, 'RB': 6},
#  '泊': {'XSC': 2},
#  'たいです': {'AV': 9},
#  'レイ': {'NN': 6},
#  '救う': {'VV': 2},
#  '為': {'NB': 22, 'NN': 1},
#  '自身': {'NN': 24},
#  '蘇ら': {'VV': 1},
#  'せる': {'AV': 62},
#  '事': {'NN': 71},
#  '黒姫': {'NNP': 2},
#  '志願': {'VV': 5},
#  '復活': {'VV': 7, 'NN': 5},
#  '後輪': {'NN': 1},
#  '駆動': {'NN': 4},
#  '変更': {'NN': 13, 'VV': 20},
#  'ワイド': {'NN': 3},
#  'トレッド': {'NNP': 1},
#  '足': {'NN': 19},
#  '回り': {'NN': 1, 'VV': 1, 'AV': 1},
#  '大型': {'NN': 8, 'JN': 3},
#  'ブリ': {'NN': 1},
#  'スター': {'NN': 7},
#  'フェンダー': {'NN': 1},
#  '包ま': {'VV': 1},
#  'エアインテーク': {'NNP': 1},
#  'イタリア': {'NNP': 12},
#  '尽': {'NN': 2},
#  'くめ': {'VV': 1},
#  '装備': {'NN': 6, 'VV': 6},
#  '品': {'XS': 5, 'NN': 3, 'XSC': 2},
#  'とも': {'XS': 26, 'NNP': 1, 'PC': 1},
#  '相まっ': {'VV': 2},
#  'ラテン': {'NNP': 2},
#  '香り': {'NN': 5},
#  '強く': {'JJ': 12},
#  '漂う': {'VV': 3},
#  'モデル': {'NN': 24},
#  '犯人': {'NN': 4},
#  '検挙': {'VV': 3},
#  'おら': {'AV': 15, 'VV': 5},
#  'ず': {'AV': 148},
#  '2012': {'CD': 24},
#  '8月': {'NR': 40},
#  '現在': {'NR': 31, 'NN': 71},
#  '未解決': {'JN': 1},
#  '山陽新幹線': {'NNP': 1},
#  '厚狭駅': {'NNP': 1},
#  '-': {'SYM': 25, 'XPC': 44, 'NN': 44},
#  '新下関駅': {'NNP': 2},
#  '小倉駅': {'NNP': 1},
#  '山陽本線': {'NNP': 2},
#  '長府': {'NNP': 1},
#  '幡生': {'NNP': 2},
#  '*': {'SYM': 10},
#  '当': {'XP': 13, 'XS': 1, 'NN': 1},
#  '始発': {'NN': 2},
#  'みすゞ潮彩': {'NNP': 1},
#  '下関駅': {'NNP': 1},
#  '間': {'XS': 45, 'NB': 41, 'NN': 6},
#  '停車': {'VV': 3, 'NN': 2},
#  '石川県': {'NNP': 3},
#  '出身': {'NN': 41},
#  '店員': {'NN': 12},
#  'さん': {'XS': 103, 'NN': 8, 'VV': 1},
#  '接客': {'NN': 12, 'VV': 2},
#  'とても': {'RB': 68, 'PK': 3},
#  '良かっ': {'JJ': 8, 'XA': 2},
#  '徒歩': {'NN': 6},
#  '15': {'CD': 37},
#  '分': {'XSC': 46, 'XS': 8, 'NN': 4, 'NB': 3},
#  '港': {'NNP': 2, 'XS': 6},
#  'いける': {'VV': 1},
#  'アクセス': {'NN': 7, 'VV': 3},
#  '便利': {'JN': 13},
#  'でし': {'XV': 17, 'AV': 71},
#  '民間': {'NN': 10},
#  '金融機関': {'NN': 2},
#  '金融サービス': {'NN': 1},
#  '拡充': {'NN': 1, 'VV': 2},
#  '本来': {'NN': 8, 'JN': 1, 'NR': 4},
#  '郵便貯金': {'NN': 1},
#  '業務': {'NN': 13},
#  '枠': {'NN': 5, 'XS': 5},
#  '超え': {'VV': 11},
#  'ドイツテレコム': {'NNP': 1},
#  '赤字': {'NN': 4},
#  '補てん': {'NN': 1},
#  '公正': {'JN': 2, 'NN': 1},
#  '競争': {'NN': 4},
#  'など': {'PA': 487, 'RB': 4},
#  '批判': {'VV': 12, 'NN': 5},
#  '研究': {'NN': 24, 'VV': 10},
#  '携わっ': {'VV': 3},
#  '山下': {'NNP': 2},
#  '孝之': {'NNP': 1},
#  '教授': {'NN': 13},
#  'がん': {'NN': 2},
#  '治療': {'NN': 19, 'VV': 1},
#  '細胞': {'NN': 7},
#  'そのもの': {'NN': 8},
#  '増殖': {'NN': 1, 'VV': 1},
#  '抑える': {'VV': 3},
#  'だっ': {'AV': 142, 'XV': 18},
#  '悪性': {'NN': 1},
#  '化': {'XS': 33, 'VV': 9, 'AV': 1},
#  '新しい': {'JJ': 29},
#  'できる': {'VV': 56, 'AV': 67},
#  'かもしれ': {'AV': 18},
#  '話し': {'VV': 9},
#  'ドル': {'NN': 12, 'XSC': 7},
#  '主要': {'JN': 7, 'NN': 6},
#  '通貨': {'NN': 3},
#  '弱含み': {'NN': 1},
#  'ぶり': {'XS': 25, 'VV': 1},
#  '高値': {'NN': 2},
#  '水準': {'NN': 7},
#  '推移': {'VV': 2, 'NN': 2},
#  'ほか': {'NB': 31, 'NN': 15},
#  '英': {'NNP': 4},
#  'ポンド': {'NN': 1, 'XSC': 3},
#  '4月': {'NR': 40},
#  '豪ドル': {'NN': 3},
#  '2': {'CD': 278},
#  '月': {'XSC': 28, 'NN': 8, 'XP': 3},
#  '映像': {'NN': 14},
#  'HD': {'NNP': 1},
#  'リマスター': {'NNP': 1},
#  '収録': {'NN': 6, 'VV': 11},
#  '6月': {'NR': 39},
#  '19': {'CD': 22},
#  '日': {'XSC': 395, 'XP': 8, 'XS': 12, 'NN': 32, 'NNP': 3},
#  '保釈金': {'NN': 1},
#  '支払い': {'VV': 1, 'NN': 5},
#  '釈放': {'VV': 1},
#  '7月': {'NR': 38},
#  'イングランド': {'NNP': 2},
#  '艦隊': {'NN': 15},
#  '義勇': {'NN': 2},
#  '兵': {'NN': 10},
#  'ノルウェー': {'NNP': 1},
#  'ベルゲン': {'NNP': 1},
#  'オランダ': {'NNP': 1},
#  '共和国': {'NN': 6},
#  '交戦': {'NN': 2, 'VV': 1},
#  '経験': {'VV': 7, 'NN': 13},
#  '手首': {'NN': 2},
#  '釘': {'NN': 1},
#  '貫か': {'VV': 1},
#  '明': {'NNP': 1, 'NN': 3},
#  'ら': {'XS': 61},
#  '痕': {'XS': 2},
#  'まずは': {'CC': 6},
#  '下記': {'NN': 5},
#  'ご覧下さい': {'VV': 1},
#  '国内': {'NN': 29},
#  '最多': {'NN': 8, 'XPC': 2},
#  '店舗数': {'NN': 1},
#  '誇る': {'VV': 6},
#  '今月': {'NR': 5},
#  '22': {'CD': 31},
#  '今回': {'NR': 35},
#  '現場': {'NN': 15},
#  'わずか': {'RB': 10, 'JN': 1},
#  '260': {'CD': 1},
#  'メートル': {'XSC': 11, 'NN': 2},
#  'ほど': {'PA': 62},
#  '事務所': {'NN': 15},
#  '出火': {'VV': 1, 'NN': 1},
#  'おり': {'AV': 162, 'VV': 1, 'NN': 1},
#  '警察': {'NN': 18},
#  'よる': {'VV': 47},
#  '放火': {'NN': 1},
#  '可能性': {'NN': 26},
#  'いう': {'VV': 119},
#  '球界': {'NN': 3},
#  '話題': {'NN': 13},
#  '独占': {'VV': 4},
#  '次代': {'NN': 2},
#  'エース': {'NN': 4},
#  'に対し': {'PS': 28},
#  'ダルビッシュ': {'NNP': 1},
#  'ルーキー': {'NN': 4},
#  '振り返り': {'VV': 2},
#  'ながら': {'PC': 63},
#  '苦笑': {'NN': 1},
#  '交じり': {'NN': 1},
#  '比較': {'VV': 6, 'NN': 1},
#  '人数': {'NN': 3},
#  '予算': {'NN': 8},
#  '合わせ': {'VV': 16},
#  '飲み': {'NN': 3, 'VV': 4},
#  '会': {'XS': 32, 'NN': 13},
#  'やすい': {'AJ': 20},
#  '元': {'JR': 26, 'XSC': 1, 'NN': 10, 'XS': 9},
#  'ダイエー': {'NNP': 1},
#  '藤本': {'NNP': 2},
#  '博史': {'NNP': 1},
#  '並び': {'VV': 1, 'NN': 1},
#  'プロ野球選手': {'NN': 1},
#  '珍しい': {'JJ': 5},
#  '柔道': {'NN': 2},
#  '有段者': {'NN': 1},
#  'ごく': {'RB': 5},
#  '少数': {'NN': 4},
#  '女性': {'NN': 69},
#  '歌手': {'NN': 3},
#  '男性': {'NN': 36},
#  '歌う': {'VV': 7},
#  '政界': {'NN': 3},
#  '人物': {'NN': 31},
#  '人脈': {'NN': 2},
#  '形成': {'VV': 12, 'NN': 3},
#  'アジア': {'NN': 7},
#  '注目': {'VV': 6, 'NN': 5},
#  'れる': {'AV': 339},
#  '中': {'NB': 95, 'NN': 7, 'XS': 83, 'XP': 6, 'NNP': 3},
#  '株価': {'NN': 5},
#  '騰落率': {'NN': 1},
#  'マイナス': {'XPC': 1, 'JN': 1, 'NN': 3},
#  '%': {'XSC': 79, 'SYM': 1},
#  'NTTコム': {'NNP': 1},
#  '別会社': {'NN': 2},
#  'NTTコミュニケーションズ': {'NNP': 1},
#  '指す': {'VV': 3},
#  '注意': {'NN': 9, 'VV': 6},
#  '必要': {'JN': 46, 'NN': 21},
#  '種類': {'NN': 14, 'XSC': 10},
#  '多数': {'NR': 19},
#  '追加': {'VV': 8, 'NN': 4},
#  '魔力': {'NN': 2},
#  '高める': {'VV': 3},
#  '他の': {'JR': 43},
#  '種族': {'NN': 2},
#  '扱': {'VV': 1},
#  'え': {'AV': 16, 'NN': 4},
#  '存在': {'VV': 31, 'NN': 15},
#  'Siri': {'NNP': 1},
#  '技術': {'NN': 29},
#  '領域': {'NN': 5},
#  '会話': {'NN': 6},
#  'インターフェース': {'NN': 1},
#  '人的': {'JN': 2},
#  '文脈': {'NN': 2},
#  '認識': {'NN': 4, 'VV': 5},
#  'サービス': {'NN': 39},
#  '代理': {'NN': 5},
#  '実行': {'NN': 3, 'VV': 11},
#  'こういう': {'JR': 5},
#  '理屈': {'NN': 3},
#  '一時': {'NR': 14},
#  '“': {'SYM': 272},
#  '城': {'XS': 17, 'NN': 3},
#  '”': {'SYM': 269},
#  '建設': {'VV': 13, 'NN': 19},
#  'よう': {'AV': 91, 'XS': 5},
#  'そうです': {'AV': 14},
#  '結局': {'NR': 16},
#  'それ': {'NP': 120},
#  '頓挫': {'VV': 1},
#  '正面': {'NN': 4},
#  '扉': {'NN': 7},
#  'なく': {'AV': 109, 'JJ': 51},
#  '四方': {'NN': 1},
#  '開放': {'VV': 4, 'NN': 2},
#  '公開': {'VV': 17, 'NN': 6},
#  '初めて': {'RB': 32},
#  'ネイト': {'NNP': 1},
#  'たち': {'XS': 78, 'NN': 2},
#  '黄金': {'NN': 1},
#  '都市': {'NN': 14},
#  '探す': {'VV': 1},
#  '上位': {'NN': 5},
#  '10': {'CD': 95},
#  '曲': {'XSC': 4, 'NN': 14, 'XS': 11},
#  '以下': {'NN': 44, 'NB': 5},
#  '通り': {'NB': 20, 'XS': 15, 'NN': 3, 'VV': 1},
#  'ウィンターカップ': {'NNP': 1},
#  '出場': {'VV': 12, 'NN': 13},
#  '功績': {'NN': 4},
#  '武勇': {'NN': 1},
#  'スペイン': {'NNP': 8},
#  '英雄': {'NN': 4, 'NNP': 1},
#  '扱い': {'VV': 5, 'NN': 1},
#  '王家': {'NN': 2},
#  'ガンディア': {'NNP': 1},
#  '公爵': {'NN': 2},
#  '地位': {'NN': 9},
#  '与え': {'VV': 20, 'NN': 1},
#  'られ': {'AV': 222},
#  'リスナー': {'NN': 5},
#  'ヒット曲': {'NN': 2},
#  'に関する': {'PS': 21},
#  '疑問': {'NN': 3, 'JN': 2},
#  'について': {'PS': 135},
#  '作詞家': {'NN': 1},
#  '作曲家': {'NN': 3},
#  '証言': {'NN': 4, 'VV': 1},
#  '集め': {'VV': 17, 'NN': 1},
#  '紹介': {'VV': 30, 'NN': 3},
#  '関西': {'NNP': 10},
#  '鉄道': {'NN': 18},
#  '社長': {'NN': 12},
#  '東京': {'NNP': 43},
#  '馬車': {'NN': 3},
#  '株式会社': {'NN': 12},
#  '取締役': {'NN': 2},
#  '株式取引所': {'NN': 1},
#  '理事長': {'NN': 6},
#  '清': {'NNP': 7},
#  '生命保険会社': {'NN': 1},
#  '等': {'XS': 37, 'PA': 6, 'NN': 3, 'XSC': 1},
#  '歴任': {'VV': 4},
#  '更に': {'RB': 16},
#  '繊維': {'NN': 1},
#  '水着': {'NN': 2},
#  'なら': {'VV': 13, 'AV': 38, 'XA': 15, 'XV': 2},
#  'グループ': {'NN': 23, 'XS': 8},
#  '事業': {'NN': 24},
#  '全体': {'NN': 25, 'RB': 2},
#  'PR': {'NN': 1, 'VV': 1},
#  '担わ': {'VV': 1},
#  '33': {'CD': 7},
#  '旭化成': {'NNP': 1},
#  'キャンペーンモデル': {'NN': 1},
#  '名称': {'NN': 17},
#  '今に': {'RB': 1},
#  '至っ': {'VV': 8},
#  '1985': {'CD': 5},
#  '現役引退': {'NN': 2},
#  'ホテル': {'NN': 18},
#  '地下': {'NN': 9},
#  '雰囲気': {'NN': 40},
#  'いまいち': {'JN': 2},
#  '破裂': {'VV': 1},
#  '心臓': {'NN': 2},
#  'すら': {'PK': 10},
#  '治': {'VV': 2},
#  '超能力': {'NN': 4},
#  '佐藤': {'NNP': 6},
#  '氏': {'XS': 125, 'NN': 5},
#  '病気': {'NN': 9},
#  'なかっ': {'AV': 99, 'JJ': 22},
#  'わけ': {'NB': 23, 'NN': 1},
#  '濃く': {'JJ': 2},
#  'あっさり': {'RB': 2},
#  '丁度': {'RB': 4},
#  '英国政府': {'NNP': 1},
#  '公的機関': {'NN': 2},
#  'イングリッシュ': {'NN': 3},
#  'ネイチャー': {'NN': 2},
#  'ヘリテッジ': {'NNP': 1},
#  '協力': {'VV': 10, 'NN': 8},
#  '活動': {'NN': 61, 'VV': 11},
#  'すすめ': {'VV': 1},
#  '25': {'CD': 31},
#  '回': {'XSC': 78, 'NN': 2, 'XS': 2},
#  '新': {'XP': 36, 'NN': 3},
#  'コーナー': {'NN': 13},
#  '祭り': {'NN': 5},
#  '登場': {'VV': 47, 'NN': 7},
#  '『': {'SYM': 218},
#  'スター・ウォーズ': {'NNP': 2},
#  '』': {'SYM': 215},
#  'ダース': {'NN': 1},
#  'ベイダー': {'NNP': 1},
#  '役': {'XS': 14, 'XSC': 2, 'NN': 6},
#  'オーディション': {'NN': 2},
#  '受け': {'VV': 91},
#  '死亡': {'VV': 18, 'NN': 8},
#  '少女': {'NN': 15},
#  '母親': {'NN': 9},
#  '本紙': {'NN': 18},
#  '取材': {'NN': 24, 'VV': 4},
#  '和解': {'NN': 6, 'VV': 1},
#  '判決': {'NN': 8},
#  '目指し': {'VV': 14},
#  '意向': {'NN': 5},
#  '示し': {'VV': 18},
#  '協議': {'NN': 8, 'VV': 5},
#  '席': {'NN': 7, 'XSC': 4, 'XS': 4},
#  '堀': {'NN': 1, 'NNP': 2},
#  '代表': {'NN': 26, 'VV': 4},
#  '拒否': {'VV': 10, 'NN': 3},
#  '1970': {'CD': 12},
#  '放送': {'NN': 27, 'VV': 18},
#  '2000': {'CD': 19},
#  '28': {'CD': 12},
#  '30': {'CD': 35},
#  '年間': {'XSC': 23, 'NN': 6},
#  'わたり': {'VV': 3},
#  '出演': {'NN': 8, 'VV': 16},
#  '今まで': {'RB': 7},
#  '通っ': {'VV': 21},
#  '値段': {'NN': 22},
#  '半額': {'NN': 2, 'NR': 1},
#  '正直': {'JN': 3, 'NN': 2},
#  '不安': {'JN': 4, 'NN': 3},
#  '生徒': {'NN': 16},
#  'もちろん': {'RB': 20},
#  '職員': {'NN': 10},
#  '人気': {'NN': 43},
#  '近年': {'NN': 10, 'NR': 5},
#  'うたばん': {'NNP': 1},
#  '逆手': {'NN': 2},
#  '取り': {'VV': 10, 'XS': 1},
#  '笑い': {'NN': 2},
#  'ネタ': {'NN': 12},
#  '積極的': {'JN': 13},
#  '活用': {'VV': 10, 'NN': 5},
#  '番組': {'NN': 26},
#  '現れ': {'VV': 14},
#  '写真': {'NN': 26},
#  '結婚式': {'NN': 6},
#  '以来': {'NR': 12},
#  'はじめ': {'NR': 3, 'VV': 3, 'AV': 1, 'PH': 7},
#  '緊張': {'VV': 5},
#  'adam': {'NNP': 1},
#  'その場': {'NN': 6},
#  'リラックス': {'VV': 8},
#  'トーク': {'NN': 8},
#  'おかげ': {'NN': 7},
#  '最終的': {'JN': 14},
#  'ノリノリ': {'JN': 1},
#  '撮影': {'NN': 10, 'VV': 12},
#  '行う': {'VV': 45},
#  'でき': {'VV': 57, 'AV': 64},
#  '単に': {'RB': 3},
#  '好み': {'NN': 5, 'VV': 2},
#  '問題': {'NN': 71, 'VV': 4},
#  'って': {'PQ': 22},
#  '言っ': {'VV': 22},
#  'たら': {'AV': 46, 'NN': 2},
#  '肉々しー': {'JJ': 1},
#  '感じ': {'NN': 40, 'VV': 25},
#  '漢': {'NN': 5},
#  '多い': {'JJ': 73},
#  'イメージ': {'NN': 14, 'VV': 3},
#  '個室': {'NN': 8},
#  '女子': {'NN': 5},
#  '気軽': {'JN': 6, 'NN': 1},
#  '行ける': {'VV': 2},
#  '良い': {'XA': 2, 'JJ': 30, 'AJ': 4},
#  '♪': {'SYM': 7},
#  '劇場版': {'NN': 2},
#  '作': {'XSC': 13, 'XS': 28, 'NN': 1, 'VV': 1},
#  '生身': {'NN': 1},
#  '人間': {'NN': 18},
#  '機械化': {'NN': 3},
#  '人': {'XS': 31, 'NN': 98, 'XSC': 194, 'XP': 6},
#  '生じ': {'VV': 8},
#  '抗争': {'NN': 4},
#  'により': {'PS': 90},
#  '廃墟': {'NN': 1},
#  '化し': {'VV': 5},
#  'パーフェクトリバティー': {'NNP': 1},
#  '教団': {'NN': 9},
#  '本部': {'NN': 8, 'NNP': 2},
#  '敷地内': {'NN': 1},
#  '立地': {'VV': 1, 'NN': 4},
#  'シリンダー': {'NN': 3},
#  'によって': {'PS': 121},
#  '噴射': {'NN': 1, 'VV': 2},
#  '吸入': {'NN': 1},
#  'やや': {'RB': 18, 'NN': 1},
#  'タイムラグ': {'NN': 1},
#  '発生': {'VV': 22, 'NN': 5},
#  '当然': {'JN': 2, 'NN': 1, 'RB': 1},
#  '燃焼': {'NN': 2},
#  '制御': {'NN': 10, 'VV': 2},
#  '大雑把': {'JN': 2},
#  'シルビア': {'NNP': 2},
#  '富士': {'NNP': 1, 'NN': 1},
#  'グラン': {'NNP': 1},
#  'チャンピオン': {'NN': 2},
#  'レース': {'NN': 17},
#  'スーパー': {'NN': 6},
#  'シルエット': {'NN': 1},
#  '参戦': {'VV': 2, 'NN': 3},
#  '近代': {'NN': 7},
#  '鉱物学': {'NN': 1},
#  '延長': {'NN': 6, 'VV': 2},
#  '結晶学': {'NN': 1},
#  '的': {'JN': 14, 'NN': 2},
#  '手法': {'NN': 6},
#  '長足': {'NN': 1},
#  '進歩': {'NN': 1},
#  '遂げ': {'VV': 5},
#  '人工': {'NN': 2},
#  '合成': {'VV': 4, 'NN': 1},
#  '出来': {'AV': 13, 'NN': 2, 'VV': 18},
#  '結晶構造': {'NN': 1},
#  '物質': {'NN': 8},
#  '見いだす': {'VV': 1},
#  '水槽': {'NN': 3},
#  '財団法人': {'NN': 1},
#  '自治': {'NN': 2},
#  '総合': {'NN': 6, 'VV': 1},
#  'センター': {'NN': 15},
#  '支援': {'NN': 21, 'VV': 13},
#  '9月': {'NR': 43},
#  '全': {'NN': 13, 'XP': 16},
#  '13': {'CD': 34},
#  '校': {'XSC': 5, 'XS': 4},
#  '各': {'XPC': 4, 'XP': 33},
#  '週': {'XSC': 3, 'NN': 4, 'XS': 3, 'XP': 1},
#  '展示': {'NN': 5, 'VV': 2},
#  '加え': {'VV': 16},
#  'リリース': {'NN': 9, 'VV': 8},
#  '方法': {'NN': 28},
#  '小安峡': {'NNP': 1},
#  '取れ': {'VV': 5},
#  '山菜': {'NN': 1},
#  '物': {'NN': 12, 'XS': 4},
#  'おいしかっ': {'JJ': 4},
#  '血': {'NN': 5},
#  '争': {'VV': 1},
#  'ハル': {'NNP': 3},
#  'マトモ': {'NNP': 1},
#  '薬': {'NN': 9, 'XS': 1},
#  '利か': {'VV': 2},
#  '体質': {'NN': 3},
#  '長髪': {'NN': 1},
#  '苫米地': {'NNP': 1},
#  '英人': {'NNP': 1},
#  'ニコラウス': {'NNP': 1},
#  '4': {'CD': 149},
#  '世': {'XSC': 32, 'XS': 4, 'NN': 1},
#  '大いに': {'RB': 4},
#  '歓迎': {'VV': 2, 'NN': 1},
#  'キリスト教徒': {'NN': 6},
#  '君主': {'NN': 2},
#  'アルグン': {'NNP': 2},
#  '称讃': {'VV': 1},
#  '返書': {'NN': 1},
#  '聖地': {'NN': 3},
#  'エルサレム': {'NNP': 3},
#  '奪還': {'VV': 1, 'NN': 1},
#  '王国': {'NN': 8},
#  '解放': {'NN': 2, 'VV': 3},
#  '遠からず': {'RB': 1},
#  '容易': {'JN': 4},
#  '達成': {'VV': 11, 'NN': 3},
#  'であろ': {'AV': 5},
#  'う': {'AV': 113},
#  '入城': {'NN': 1},
#  '進言': {'VV': 2},
#  '本': {'XP': 36, 'XSC': 24, 'NN': 9, 'XS': 3},
#  '会議場': {'NN': 1},
#  '特別委員会': {'NN': 1},
#  '室': {'XS': 10, 'XSC': 1},
#  '議論': {'NN': 6, 'VV': 5},
#  '進む': {'VV': 8},
#  '傍ら': {'NN': 6},
#  '居眠り': {'NN': 1},
#  '私語': {'VV': 1},
#  '途中': {'NR': 18},
#  '離席': {'NN': 1},
#  '議員': {'NN': 19},
#  '姿': {'NN': 32},
#  'ちらほら': {'RB': 1},
#  '見受け': {'VV': 2},
#  'R': {'NNP': 10},
#  '12': {'CD': 54},
#  '1932': {'CD': 4},
#  '27': {'CD': 16},
#  'ニューロンドン': {'NNP': 1},
#  '出航': {'VV': 2},
#  'ペンシルベニア州': {'NNP': 3},
#  'フィラデルフィア': {'NNP': 1},
#  '向かい': {'VV': 3, 'NN': 2},
#  '12月': {'NR': 33},
#  '退役': {'VV': 2},
#  '級': {'XS': 15, 'NN': 2, 'XSC': 5},
#  '潜水艦': {'NN': 3},
#  'と共に': {'PP': 34},
#  '予備役': {'NN': 3},
#  '保管': {'VV': 3},
#  '締め切り': {'NN': 1},
#  '開催': {'NN': 11, 'VV': 27},
#  '流行': {'NN': 7, 'VV': 2},
#  'カラー': {'NN': 6},
#  'キャメル': {'NNP': 1},
#  '色': {'XS': 6, 'NN': 16, 'XSC': 1},
#  'コート': {'NN': 3},
#  '羽織り': {'VV': 1},
#  'スモッグ': {'NN': 1},
#  '効果': {'NN': 22},
#  '照明': {'NN': 9},
#  '利用': {'VV': 65, 'NN': 9},
#  '神秘的': {'JN': 2},
#  'でも': {'AV': 29, 'CC': 12},
#  'シック': {'JN': 1},
#  '魅力': {'NN': 9},
#  '発揮': {'VV': 11},
#  'セット': {'NN': 13},
#  'イチオシ': {'NNP': 1},
#  '太陽': {'NN': 6},
#  '50': {'CD': 19},
#  '質量': {'NN': 2},
#  '星': {'NN': 4, 'XS': 4, 'NNP': 4},
#  '一生': {'NN': 2, 'NR': 1},
#  '1000': {'CD': 11},
#  '億': {'CD': 27, 'NN': 11},
#  '以上': {'NB': 48, 'NN': 4, 'XSC': 3},
#  '及ぶ': {'VV': 4},
#  '9': {'CD': 44},
#  '夜': {'NN': 17, 'XPC': 1, 'XSC': 2},
#  '風邪': {'NN': 1},
#  '症状': {'NN': 6},
#  '訴え': {'VV': 8, 'NN': 3},
#  'グラウンド': {'NN': 3},
#  '見せ': {'VV': 17},
#  '会場': {'NN': 16},
#  '小': {'XP': 10, 'NN': 1},
#  'ホール': {'NN': 3},
#  '統一': {'NN': 50, 'VV': 3},
#  '協会': {'NN': 57},
#  '信者': {'NN': 74},
#  '講演会': {'NN': 2},
#  '訪れ': {'VV': 21, 'NN': 1},
#  '一般': {'NN': 23},
#  '記者': {'NN': 32},
#  '含め': {'VV': 23},
#  '5': {'CD': 97},
#  '程': {'PA': 6, 'NN': 3},
#  '決勝': {'NN': 14},
#  '進ん': {'VV': 14},
#  '梅沢': {'NNP': 1},
#  '杉本': {'NNP': 2},
#  'まちゃ': {'NNP': 1},
#  'RIKACO': {'NNP': 1},
#  '高級感': {'NN': 2},
#  '溢れ': {'VV': 5},
#  '先方': {'NN': 1},
#  '満足': {'NN': 8, 'VV': 15, 'JN': 3},
#  'らしく': {'AV': 9},
#  '接待': {'NN': 2},
#  'いい': {'JJ': 49, 'VV': 3},
#  '魔界': {'NN': 2},
#  'マグマ': {'NN': 1},
#  '同じ': {'JN': 28, 'JR': 24, 'VV': 1},
#  '成分': {'NN': 3},
#  'キルバーン': {'NNP': 1},
#  '血液': {'NN': 5},
#  '性質': {'NN': 5},
#  '彼': {'NP': 66},
#  '切り札': {'NN': 1},
#  '大学野球': {'NN': 1},
#  '札幌': {'NNP': 2},
#  '学生野球': {'NN': 1},
#  '連盟': {'NN': 7},
#  'うち': {'NB': 32, 'NN': 2, 'JR': 1},
#  '三部': {'NN': 1},
#  'リーグ戦': {'NN': 3},
#  '行わ': {'VV': 80},
#  '毎回': {'NN': 9},
#  '70': {'CD': 11},
#  '前後': {'XS': 8, 'NN': 2, 'VV': 1},
#  '集める': {'VV': 6},
#  'コンサート': {'NN': 8},
#  '育ち': {'VV': 2},
#  'つつ': {'PC': 17},
#  '三十五': {'CD': 1},
#  '小学生': {'NN': 5},
#  '作品': {'NN': 53},
#  'かなり': {'NR': 38, 'RB': 2},
#  '経堂': {'NN': 1},
#  ...}

# %%
import sys
import json
import math

# %%
def split_word_tag_token(token):
    if len(token.split('/')) == 2:
        w = token.split('/')[0]
        t = token.split('/')[1]
    else:
        t = token.split('/')[-1]
        w = ''.join(token.split('/')[:-1])
    return w, t

# %%
path_to_input = "./hmm-training-data/it_isdt_dev_raw.txt"
with open('./hmmmodel.txt', 'r') as reader:
    hmm_model = json.load(reader)

sents = []
out_setns = []
with open(path_to_input, 'r') as reader:
    for line in reader:
        sents.append(line.strip())

# %%
sent = "ただし 、 50 周年 ソング に 変更 後 は 、 ED も 歌 つき の もの が 使わ れ た 。"

# %%
def handle_unseen(T, idx, b):
    if T[idx] not in b.keys():
        b[T[idx]] = b['##unseen##']

# %%
# Viterbi
back_pointer = {}
T = sent.split(' ')
Q = hmm_model['tag']
a = hmm_model['p_transition']
b = hmm_model['p_emission']
q0 = '#Q0'
qt = '#QT'
num_q = len(Q)
num_t = len(T)
# Initialize by 1 which is INF here and will be skip for unreachable state
prob = [[2 for t in range(num_t + 1)] for q in range(num_q)] # num_t + 1 include last state QT

# Note:
# cal neg value --> find max arg --> skip no value
# or negate to get pos value -> find min --> like find min entropy

# TODO - Smoothing a[q'][q] == 0
# initialize at step t_0
for iq, q in enumerate(Q):
    back_pointer[q] = {} # initialize backpointer with all key 'q' in Q
    # TODO - handle unseen word b[T[0]]
    handle_unseen(T, 0, b)
    if a[q0][q] == 0 or b[T[0]][q] == 0:
        continue
    prob[iq][0] = math.log(a[q0][q]) + math.log(b[T[0]][q])
    back_pointer[q][0] = q0
    # Handle no transition

# Run from step t_1 to t_T
for t in range(1, num_t):
    # find argmax prob
    argmax_b = 1
    has_transition = False
    for iq, q in enumerate(Q):
        for ipq, pq in enumerate(Q): # Enumerate every q in previous t 
            handle_unseen(T,t,b)
            if prob[ipq][t-1] == 2 or a[pq][q] == 0 or b[T[t]][q] == 0:
                continue
            if prob[iq][t] == 2:
                prob[iq][t] = prob[ipq][t-1] + math.log(a[pq][q]) + math.log(b[T[t]][q])
                argmax_b = prob[ipq][t-1] + math.log(a[pq][q])
                back_pointer[q][t] = pq
                if t == 23:
                    print("Assign q:{} t:{} to pq:{}".format(q,t,pq))
                has_transition = True
            else:
                prob[iq][t] = max(prob[iq][t], prob[ipq][t-1] + math.log(a[pq][q]) + math.log(b[T[t]][q]))
                if prob[ipq][t-1] + math.log(a[pq][q]) > argmax_b:
                    argmax_b = prob[ipq][t-1] + math.log(a[pq][q])
                    back_pointer[q][t] = pq
                    if t == 23:
                        print("Assign q:{} t:{} to pq:{}".format(q,t,pq))
                    
    if not has_transition:
        print("No Transition at {}".format(T[t]))
        # Prob: when state 't' is unreachable
        # case: there is only one transition to QT and that word has no b[w][pos] value
        # Or the only b[w][pos] we have is not reachable
        # Sol: use most likely tag for current 't' and use most likely tag for prev t
        max_prev_t = 2
        most_likely_pq = None
        for ipq, pq in enumerate(Q):
            if prob[ipq][t-1] == 2:
                continue
            if max_prev_t == 2:
                max_prev_t = prob[ipq][t-1]
                most_likely_pq = pq
            else:
                if prob[ipq][t-1] > max_prev_t:
                    max_prev_t = prob[ipq][t-1]
                    most_likely_pq = pq
         
        max_cur_emission = 2
        cq = None
        most_liekly_iq = -1
        for iq, q in enumerate(Q):
            if b[T[t]][q] == 0:
                continue
            if max_cur_emission == 2:
                max_cur_emission = math.log(b[T[t]][q])
                cq = q
                most_liekly_iq = iq
            else:
                if math.log(b[T[t]][q]) > max_cur_emission:
                    max_cur_emission = math.log(b[T[t]][q])
                    cq = q
                    most_liekly_iq = iq
        back_pointer[cq][t] = most_likely_pq
        prob[most_liekly_iq][t] = max_prev_t + max_cur_emission
        print("Put transition from {}/{} to previous state {}/{}".format(T[t],cq,T[t-1], most_likely_pq))
        print(back_pointer[cq])

# At termination step: QT
bpt_qt = None
argmax_qt = 2
for iq, q in enumerate(Q):
    # TODO - add smoothing when a[q][qt] == 0
    # Edge case: there is only one transition to QT and that word has no a[q][qt] value
    if prob[iq][num_t-1] == 2 or a[q][qt] == 0:
        continue
    if argmax_qt == 2:
        argmax_qt = prob[iq][num_t-1] + math.log(a[q][qt])
        bpt_qt = q
    else:
        if prob[iq][num_t-1] + math.log(a[q][qt]) > prob[iq][num_t]:
            prob[iq][num_t] = max(prob[iq][num_t], math.log(a[q][qt]))
            bpt_qt = q

# Return backtrack path
q = bpt_qt
sent_tag = []
t = len(T)-1
while q != '#Q0' and t >= 0:
    print("Word: {} Q: {}, t: {}".format(T[t],q, t))
    sent_tag.append(q)
    q = back_pointer[q][t]
    t -= 1
sent_tag.reverse()
sent_tag
# Out:
# Word: 。 Q: SYM, t: 20
# Word: た Q: AV, t: 19
# Word: れ Q: AV, t: 18
# Word: 使わ Q: VV, t: 17
# Word: が Q: PS, t: 16
# Word: もの Q: NB, t: 15
# Word: の Q: PN, t: 14
# Word: つき Q: XS, t: 13
# Word: 歌 Q: NN, t: 12
# Word: も Q: PK, t: 11
# Word: ED Q: NN, t: 10
# Word: 、 Q: SYM, t: 9
# Word: は Q: PK, t: 8
# Word: 後 Q: NB, t: 7
# Word: 変更 Q: VV, t: 6
# Word: に Q: PS, t: 5
# Word: ソング Q: NN, t: 4
# Word: 周年 Q: XSC, t: 3
# Word: 50 Q: CD, t: 2
# Word: 、 Q: SYM, t: 1
# Word: ただし Q: CC, t: 0
# ['CC',
#  'SYM',
#  'CD',
#  'XSC',
#  'NN',
#  'PS',
#  'VV',
#  'NB',
#  'PK',
#  'SYM',
#  'NN',
#  'PK',
#  'NN',
#  'XS',
#  'PN',
#  'NB',
#  'PS',
#  'VV',
#  'AV',
#  'AV',
#  'SYM']

# %%
output = ""
for i,token in enumerate(T):
    output += "{}/{} ".format(token, sent_tag[i])
output = output.strip()
output
# Out:
# 'ただし/CC 、/SYM 50/CD 周年/XSC ソング/NN に/PS 変更/VV 後/NB は/PK 、/SYM ED/NN も/PK 歌/NN つき/XS の/PN もの/NB が/PS 使わ/VV れ/AV た/AV 。/SYM'

# %%
# Grading
import sys

def split_word_tag_token(token):
    if len(token.split('/')) == 2:
        w = token.split('/')[0]
        t = token.split('/')[1]
    else:
        t = token.split('/')[-1]
        w = ''.join(token.split('/')[:-1])
    return w, t


path_to_result = './hmmoutput.txt'
path_to_dev = './hmm-training-data/it_isdt_dev_tagged.txt'
hmm_output = []
devset = []
with open(path_to_result, 'r') as reader:
    for line in reader:
        hmm_output.append(line)
        
with open(path_to_dev, 'r') as reader:
    for line in reader:
        devset.append(line)

if len(hmm_output) != len(devset):
    raise Exception("Number of lines is not equal. Exit with Error(1)")

ntags = 0
ncorrect = 0
for i in range(0,len(devset)):
    lhmm = hmm_output[i].split(' ')
    ldev = devset[i].split(' ')
    for j in range(0, len(ldev)):
        hmm_w, hmm_t = split_word_tag_token(lhmm[j])
        dw, dt = split_word_tag_token(ldev[j])
        if hmm_w != dw:
            raise Exception("Word does not match hmm_w={} dw={}. Exit with Error(1)".format(hmm_w, dw))
        if hmm_t == dt:
            ncorrect += 1
        ntags += 1

print("Accuracy: {}%".format(ncorrect*100/ntags))
