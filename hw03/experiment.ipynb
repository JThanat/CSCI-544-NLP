# %%
import json
import os
import re
import math

# %%
with open("features.txt") as w:
    features = json.load(w)

# %%
a = set([k for k,v in features['fn']])
b = set([k for k,v in features['fp']])
c = set([k for k,v in features['ft']])
d = set([k for k,v in features['fd']])

# %%
neg_dict = {
        "can't": "can not",
        "couldn't": "could not",
        "don't": "do not",
        "doesn't": "does not",
        "didn't": "did not",
        "haven't": "have not",
        "hasn't": "has not",
        "hadn't": "had not",
        "won't": "will not",
        "would't": "would not",
        "shouldn't": "should not",
        "isn't": "is not",
        "aren't": "are not",
    }

# %%
def compute_feature_utility(docs, t, _class, feature_of_class):
    # Ntc --> t: document contain t, c: doc in class c
    # Ex: N10 -> doc that contains t (et = 1) and doc is not in class c (ec = 0)
    N00 = 0
    N11 = 0
    N01 = 0
    N10 = 0
    for c in _class:
        for doc in docs[c]:
            if c == feature_of_class:
                if t in doc:
                    N11 += 1
                else:
                    N01 += 1
            else:
                if t in doc:
                    N10 += 1
                else:
                    N00 += 1
    if N00 == 0:
        N00 += 1
    if N01 == 0:
        N01 += 1
    if N10 == 0:
        N10 += 1
    if N11 == 0:
        N11 += 1
    N = N00 + N01 + N10 + N11
    U = N11 * math.log2((N * N11) / ((N10 + N11) * (N01 + N10))) / N
    U += N01 * math.log2((N * N01) / ((N00 + N01) * (N10 + N11))) / N
    U += N10 * math.log2((N * N10) / ((N10 + N11) * (N00 + N10))) / N
    U += N00 * math.log2((N * N00) / ((N00 + N01) * (N00 + N01))) / N
    return U


def select_feature(docs, k, feature_of_class):
    nb_class = docs.keys()
    vocab = set([])
    L = []
    for _class in docs:
        for doc in docs[_class]:
            vocab.update(doc)
    for t in vocab:
        U = compute_feature_utility(docs, t, nb_class, feature_of_class)
        L.append((U, t))
    L.sort(reverse=True)
    return L

# %%
def tokenize(doc):
    # filter stopwords later
    stop_words = {}
    token_list = [x.strip() for x in re.sub(r"[^a-zA-Z ]", "", doc).split(" ") if len(x) > 0]
    return token_list

def read_file(class_folder):
    docs = []
    for fold in class_folder:
        if fold.is_dir():
            folder = os.scandir(fold.path)
            for training_file in folder:
                if ".txt" not in training_file.path or "README" in training_file.path:
                    continue
                with open(training_file.path, "r", encoding="utf-8") as file_reader:
                    doc = ""
                    for line in file_reader:
                        doc += line.lower()
                    sub_doc = multiple_replace(neg_dict, doc)
                    docs.append(sub_doc)
    return docs


def multiple_replace(dict, text):
    # Create a regular expression  from the dictionary keys
    regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))

    # For each match, look-up corresponding value in dictionary
    return regex.sub(lambda mo: dict[mo.string[mo.start():mo.end()]], text)

# %%
def remove_rare_feature(docs):
    count_token = {}
    for i, doc in enumerate(docs):
        token_set = tokenize(doc)
        for t in token_set:
            if t not in count_token:
                count_token[t] = 0
            count_token[t] += 1

    count_token = dict(filter(lambda elem: elem[1] >= 5, count_token.items()))
    sorted_x = sorted(count_token.items(), key=lambda kv: kv[1], reverse=True)
    return sorted_x

# %%
path_to_train = './train_data'
neg_dec = os.scandir(os.path.join(path_to_train, "negative_polarity/deceptive_from_MTurk"))
neg_tr = os.scandir(os.path.join(path_to_train, "negative_polarity/truthful_from_Web"))
pos_dec = os.scandir(os.path.join(path_to_train, "positive_polarity/deceptive_from_MTurk"))
pos_tr = os.scandir(os.path.join(path_to_train, "positive_polarity/truthful_from_TripAdvisor"))

neg_dec_docs = read_file(neg_dec)
neg_tr_docs = read_file(neg_tr)
pos_dec_docs = read_file(pos_dec)
pos_tr_docs = read_file(pos_tr)

neg_dec_docs_set = remove_rare_feature(neg_dec_docs)
neg_tr_docs_set = remove_rare_feature(neg_tr_docs)
pos_dec_docs_set = remove_rare_feature(pos_dec_docs)
pos_tr_docs_set = remove_rare_feature(pos_tr_docs)

# %%
def count_t(count_dict, docs):
    for t,n in docs:
        if t not in count_dict:
            count_dict[t] = 0
        count_dict[t] += n


neg_count = {}
count_t(neg_count, neg_dec_docs_set + neg_tr_docs_set)
pos_count = {}
count_t(pos_count, pos_dec_docs_set + pos_tr_docs_set)
# Out:
# {'the': 3987,
#  'and': 2259,
#  'i': 1417,
#  'to': 1486,
#  'a': 1670,
#  'was': 1472,
#  'hotel': 930,
#  'in': 929,
#  'my': 563,
#  'of': 823,
#  'chicago': 512,
#  'at': 581,
#  'we': 792,
#  'is': 671,
#  'for': 648,
#  'it': 559,
#  'room': 577,
#  'with': 470,
#  'stay': 400,
#  'this': 449,
#  'were': 453,
#  'very': 452,
#  'that': 362,
#  'you': 323,
#  'had': 335,
#  'have': 292,
#  'our': 335,
#  'great': 391,
#  'not': 355,
#  'staff': 285,
#  'all': 262,
#  'as': 252,
#  'they': 232,
#  'there': 255,
#  'are': 236,
#  'from': 310,
#  'so': 236,
#  'rooms': 216,
#  'on': 352,
#  'would': 229,
#  'stayed': 213,
#  'be': 184,
#  'service': 177,
#  'will': 154,
#  'me': 141,
#  'time': 139,
#  'when': 149,
#  'but': 248,
#  'comfortable': 161,
#  'one': 148,
#  'clean': 173,
#  'just': 153,
#  'an': 152,
#  'definitely': 110,
#  'could': 136,
#  'friendly': 147,
#  'place': 107,
#  'like': 131,
#  'recommend': 119,
#  'again': 143,
#  'city': 119,
#  'beautiful': 100,
#  'nice': 156,
#  'out': 128,
#  'if': 129,
#  'area': 102,
#  'wonderful': 108,
#  'which': 112,
#  'back': 99,
#  'really': 111,
#  'by': 112,
#  'husband': 73,
#  'experience': 85,
#  'business': 85,
#  'while': 74,
#  'also': 120,
#  'even': 92,
#  'visit': 68,
#  'well': 109,
#  'here': 130,
#  'location': 187,
#  'hotels': 91,
#  'did': 118,
#  'best': 90,
#  'next': 83,
#  'your': 80,
#  'loved': 74,
#  'their': 87,
#  'get': 104,
#  'downtown': 82,
#  'home': 65,
#  'has': 96,
#  'amazing': 65,
#  'view': 116,
#  'ever': 61,
#  'after': 72,
#  'us': 130,
#  'more': 79,
#  'everything': 91,
#  'food': 76,
#  'perfect': 83,
#  'what': 74,
#  'do': 82,
#  'up': 89,
#  'most': 61,
#  'first': 75,
#  'bed': 116,
#  'only': 98,
#  'staying': 54,
#  'or': 95,
#  'night': 119,
#  'can': 104,
#  'helpful': 104,
#  'made': 69,
#  'trip': 69,
#  'restaurant': 82,
#  'enjoyed': 68,
#  'much': 59,
#  'its': 81,
#  'family': 48,
#  'rock': 55,
#  'beds': 62,
#  'about': 105,
#  'hard': 55,
#  'felt': 49,
#  'some': 91,
#  'go': 74,
#  'omni': 57,
#  'got': 95,
#  'weekend': 57,
#  'away': 65,
#  'highly': 64,
#  'way': 48,
#  'ambassador': 50,
#  'east': 49,
#  'spacious': 76,
#  'pool': 47,
#  'than': 78,
#  'good': 98,
#  'wife': 54,
#  'looking': 40,
#  'suite': 65,
#  'because': 59,
#  'excellent': 94,
#  'day': 67,
#  'recently': 43,
#  'modern': 41,
#  'anyone': 37,
#  'where': 45,
#  'shopping': 71,
#  'luxurious': 35,
#  'many': 55,
#  'overall': 45,
#  'desk': 85,
#  'vacation': 28,
#  'feel': 48,
#  'luxury': 28,
#  'been': 52,
#  'fitness': 31,
#  'say': 55,
#  'work': 37,
#  'dinner': 50,
#  'how': 36,
#  'fantastic': 50,
#  'suites': 43,
#  'millennium': 33,
#  'hyatt': 38,
#  'located': 39,
#  'right': 70,
#  'make': 44,
#  'want': 42,
#  'able': 41,
#  'every': 56,
#  'talbott': 48,
#  'front': 66,
#  'am': 49,
#  'better': 45,
#  'nights': 60,
#  'other': 68,
#  'internet': 46,
#  'two': 63,
#  'too': 55,
#  'atmosphere': 31,
#  'elegant': 27,
#  'close': 48,
#  'extremely': 48,
#  'never': 45,
#  'no': 74,
#  'sheraton': 38,
#  'fairmont': 41,
#  'relaxing': 27,
#  'walking': 60,
#  'into': 35,
#  'need': 42,
#  'come': 31,
#  'lobby': 66,
#  'worth': 33,
#  'restaurants': 46,
#  'spa': 20,
#  'went': 34,
#  'amenities': 30,
#  'any': 44,
#  'big': 44,
#  'views': 39,
#  'return': 40,
#  'wanted': 27,
#  'find': 36,
#  'sure': 40,
#  'center': 27,
#  'affinia': 28,
#  'places': 32,
#  'around': 42,
#  'free': 64,
#  'im': 27,
#  'dining': 25,
#  'easy': 35,
#  'price': 45,
#  'see': 35,
#  'check': 43,
#  'absolutely': 32,
#  'knickerbocker': 33,
#  'regency': 19,
#  'everyone': 41,
#  'guests': 27,
#  'especially': 29,
#  'needed': 31,
#  'breakfast': 77,
#  'he': 41,
#  'delicious': 25,
#  'such': 34,
#  'ive': 34,
#  'during': 36,
#  'lot': 33,
#  'friends': 30,
#  'bar': 59,
#  'took': 31,
#  'impressed': 33,
#  'high': 34,
#  'flat': 26,
#  'tv': 37,
#  'going': 38,
#  'know': 30,
#  'always': 43,
#  'take': 44,
#  'guest': 26,
#  'accommodations': 16,
#  'enough': 34,
#  'being': 35,
#  'decor': 22,
#  'who': 36,
#  'last': 31,
#  'screen': 30,
#  'before': 35,
#  'fun': 30,
#  'visiting': 23,
#  'enjoy': 24,
#  'homewood': 27,
#  'conrad': 32,
#  'customer': 22,
#  'within': 37,
#  'distance': 47,
#  'over': 39,
#  'bathroom': 78,
#  'few': 44,
#  'upon': 28,
#  'package': 15,
#  'pet': 15,
#  'travel': 25,
#  'meeting': 22,
#  'down': 35,
#  'relax': 15,
#  'then': 31,
#  'leave': 15,
#  'she': 29,
#  'park': 35,
#  'decided': 32,
#  'indoor': 15,
#  'wine': 15,
#  'little': 45,
#  'quality': 24,
#  'access': 28,
#  'walk': 55,
#  'must': 23,
#  'quick': 22,
#  'found': 39,
#  'complimentary': 25,
#  'wedding': 14,
#  'towers': 21,
#  'however': 27,
#  'checked': 27,
#  'asked': 29,
#  'things': 21,
#  'off': 32,
#  'long': 26,
#  'available': 19,
#  'reasonable': 18,
#  'king': 31,
#  'gorgeous': 21,
#  'courteous': 18,
#  'top': 32,
#  'quite': 29,
#  'treated': 20,
#  'huge': 38,
#  'mile': 46,
#  'swissotel': 31,
#  'give': 21,
#  'favorite': 20,
#  'part': 21,
#  'professional': 22,
#  'awesome': 22,
#  'greeted': 21,
#  'booked': 44,
#  'extra': 23,
#  'kids': 18,
#  'michigan': 94,
#  'helped': 17,
#  'look': 23,
#  'polite': 18,
#  'own': 12,
#  'eat': 26,
#  'liked': 20,
#  'use': 21,
#  'concierge': 49,
#  'came': 23,
#  'heart': 18,
#  'decorated': 20,
#  'dog': 11,
#  'id': 18,
#  'spent': 18,
#  'should': 18,
#  'workout': 18,
#  'since': 28,
#  'pets': 11,
#  'pump': 24,
#  'happy': 22,
#  'them': 24,
#  'traveling': 11,
#  'incredible': 20,
#  'large': 57,
#  'navy': 40,
#  'pier': 39,
#  'love': 32,
#  'offer': 18,
#  'through': 31,
#  'thing': 21,
#  'three': 24,
#  'pleased': 20,
#  'convenient': 22,
#  'days': 27,
#  'along': 19,
#  'meal': 16,
#  'pillows': 29,
#  'magnificent': 34,
#  'gym': 25,
#  'bags': 10,
#  'left': 26,
#  'town': 19,
#  'wait': 24,
#  'itself': 21,
#  'bring': 10,
#  'beautifully': 10,
#  'think': 31,
#  'moment': 10,
#  'pleasant': 21,
#  'windy': 10,
#  'entire': 15,
#  'getaway': 10,
#  'arrived': 30,
#  'recommended': 18,
#  'believe': 10,
#  'speed': 10,
#  'comfort': 10,
#  'choice': 20,
#  'used': 27,
#  'another': 23,
#  'cool': 19,
#  'getting': 21,
#  'fast': 14,
#  'help': 16,
#  'thank': 14,
#  'both': 32,
#  'immediately': 15,
#  'door': 30,
#  'pillow': 9,
#  'needs': 9,
#  'book': 14,
#  'wireless': 15,
#  'short': 21,
#  'fabulous': 27,
#  'warm': 19,
#  'classy': 9,
#  'cozy': 18,
#  'offered': 14,
#  'though': 28,
#  'size': 28,
#  'lounge': 9,
#  'massage': 9,
#  'plan': 9,
#  'new': 25,
#  'advantage': 9,
#  'yet': 9,
#  'soft': 9,
#  'hilton': 9,
#  'walked': 23,
#  'seemed': 14,
#  'bit': 37,
#  'provided': 13,
#  'near': 19,
#  'th': 45,
#  'art': 18,
#  'having': 23,
#  'sleep': 15,
#  'anything': 25,
#  'feeling': 17,
#  'simply': 16,
#  'week': 19,
#  'knew': 8,
#  'welcoming': 14,
#  'fit': 8,
#  'ipod': 14,
#  'offers': 8,
#  'youre': 15,
#  'hour': 8,
#  'thats': 15,
#  'without': 23,
#  'forward': 8,
#  'ill': 14,
#  'seeing': 8,
#  'upscale': 14,
#  'fact': 16,
#  'coming': 8,
#  'received': 13,
#  'services': 8,
#  'romantic': 8,
#  'wifi': 13,
#  'year': 21,
#  'pleasure': 8,
#  'different': 25,
#  'pretty': 20,
#  'aquarium': 8,
#  'soon': 8,
#  'truly': 14,
#  'actually': 13,
#  'kitchen': 14,
#  'coffee': 33,
#  'five': 12,
#  'longer': 7,
#  'personal': 7,
#  'towels': 15,
#  'done': 15,
#  'gave': 15,
#  'relaxed': 7,
#  'style': 7,
#  'including': 19,
#  'reservation': 13,
#  'watch': 7,
#  'conference': 19,
#  'people': 34,
#  'thought': 18,
#  'menu': 13,
#  'making': 13,
#  'least': 12,
#  'choose': 14,
#  'local': 7,
#  'expected': 7,
#  'met': 12,
#  'her': 13,
#  'arrival': 14,
#  'spend': 7,
#  'rate': 40,
#  'recent': 7,
#  'included': 18,
#  'special': 15,
#  'furnished': 12,
#  'once': 13,
#  'attractions': 17,
#  'skyline': 7,
#  'mention': 12,
#  'beyond': 7,
#  'neat': 7,
#  'completely': 12,
#  'enjoyable': 7,
#  'spectacular': 7,
#  'club': 17,
#  'life': 7,
#  'thanks': 12,
#  'outside': 16,
#  'bedding': 7,
#  'hours': 7,
#  'floor': 64,
#  'employees': 13,
#  'kind': 16,
#  'far': 18,
#  'future': 19,
#  'river': 35,
#  'television': 7,
#  'living': 15,
#  'royalty': 7,
#  'star': 13,
#  'small': 32,
#  'call': 14,
#  'morning': 31,
#  'breathtaking': 6,
#  'quickly': 6,
#  'important': 6,
#  'him': 6,
#  'kept': 11,
#  'bath': 14,
#  'worked': 6,
#  'queen': 6,
#  'complete': 6,
#  'shower': 35,
#  'water': 26,
#  'treat': 6,
#  'nothing': 14,
#  'definetly': 6,
#  'designed': 6,
#  'something': 6,
#  'online': 6,
#  'stars': 6,
#  'lake': 33,
#  'exceptional': 6,
#  'reservations': 14,
#  'chicagos': 6,
#  'yours': 6,
#  'experienced': 6,
#  'easily': 12,
#  'helping': 6,
#  'satisfied': 6,
#  'die': 6,
#  'whether': 6,
#  'music': 15,
#  'site': 6,
#  'wish': 6,
#  'rates': 12,
#  'visited': 6,
#  'anniversary': 14,
#  'deal': 28,
#  'several': 18,
#  'times': 13,
#  'conveniently': 6,
#  'pampered': 6,
#  'sized': 12,
#  'drinks': 16,
#  'shedd': 6,
#  'system': 6,
#  'whole': 14,
#  'fine': 16,
#  'prices': 6,
#  'evening': 6,
#  'looked': 15,
#  'company': 11,
#  'taking': 6,
#  'seen': 12,
#  'else': 13,
#  'equipped': 6,
#  'still': 25,
#  'tired': 11,
#  'breath': 6,
#  'plasma': 12,
#  'spotless': 12,
#  'gold': 11,
#  'nearby': 13,
#  'brought': 5,
#  'immaculate': 5,
#  'additional': 5,
#  'stepped': 5,
#  'theres': 11,
#  'plenty': 11,
#  'welcome': 11,
#  'married': 5,
#  'until': 5,
#  'four': 14,
#  'picked': 5,
#  'set': 5,
#  'building': 20,
#  'willing': 5,
#  'person': 17,
#  'summer': 5,
#  'cocktail': 5,
#  'tell': 5,
#  'booking': 10,
#  'given': 11,
#  'let': 11,
#  'ave': 47,
#  'checkout': 5,
#  'above': 5,
#  'possible': 5,
#  'world': 5,
#  'personally': 5,
#  'each': 20,
#  'inside': 10,
#  'safe': 11,
#  'entertainment': 5,
#  'particularly': 11,
#  'slept': 13,
#  'problem': 12,
#  'provide': 5,
#  'point': 5,
#  'perfectly': 5,
#  'planning': 5,
#  'mind': 5,
#  'flight': 5,
#  'tour': 5,
#  'traveled': 5,
#  'plus': 15,
#  'lovely': 23,
#  'those': 13,
#  'filled': 5,
#  'friend': 13,
#  'couple': 16,
#  'shop': 5,
#  'matter': 5,
#  'although': 19,
#  'positive': 5,
#  'phone': 12,
#  'almost': 11,
#  'quiet': 30,
#  'ask': 12,
#  'wasnt': 16,
#  'myself': 10,
#  'notch': 12,
#  'shulas': 5,
#  'inch': 5,
#  'heated': 5,
#  'accommodating': 12,
#  'son': 10,
#  'swimming': 5,
#  'doors': 5,
#  'blocks': 34,
#  'parking': 27,
#  'reviews': 27,
#  'avenue': 25,
#  'street': 22,
#  'buffet': 20,
#  'etc': 19,
#  'corner': 19,
#  'priceline': 19,
#  'minute': 18,
#  'lots': 17,
#  'tub': 16,
#  'early': 16,
#  'checkin': 16,
#  'north': 15,
#  'comfy': 15,
#  'end': 15,
#  'now': 14,
#  'block': 14,
#  'per': 14,
#  'paid': 14,
#  'doorman': 13,
#  'old': 13,
#  'less': 13,
#  'tower': 13,
#  'areas': 13,
#  'construction': 13,
#  'full': 13,
#  'expensive': 13,
#  'open': 13,
#  'windows': 12,
#  'hancock': 12,
#  'probably': 12,
#  'upgraded': 12,
#  'noise': 12,
#  'valet': 12,
#  'fresh': 12,
#  'years': 12,
#  'hot': 12,
#  'car': 11,
#  'returned': 11,
#  'ate': 11,
#  'across': 11,
#  'superb': 11,
#  'millenium': 11,
#  'does': 11,
#  'these': 11,
#  'said': 11,
#  'yes': 11,
#  'others': 11,
#  'separate': 11,
#  'name': 10,
#  'john': 10,
#  'neighborhood': 10,
#  'cab': 10,
#  'nd': 10,
#  'called': 10,
#  'double': 10,
#  'negative': 10,
#  'read': 10,
#  'pay': 10,
#  'property': 10,
#  'ready': 10,
#  'late': 10,
#  'mall': 10,
#  'elevator': 9,
#  'loop': 9,
#  'complaint': 9,
#  'drink': 9,
#  'space': 9,
#  'requested': 9,
#  'bedroom': 9,
#  'minutes': 9,
#  'bad': 9,
#  'definately': 9,
#  'housekeeping': 9,
#  'care': 9,
#  'tvs': 9,
#  'saw': 9,
#  'might': 8,
#  'super': 8,
#  'appointed': 8,
#  'side': 8,
#  'bell': 8,
#  'show': 8,
#  'line': 8,
#  'complaints': 8,
#  'cost': 8,
#  'reception': 8,
#  'terrific': 8,
#  'try': 8,
#  'n': 8,
#  'expectations': 8,
#  'taxi': 8,
#  'airport': 8,
#  'hear': 8,
#  'larger': 8,
#  'program': 8,
#  'upgrade': 8,
#  'chose': 8,
#  'value': 8,
#  'ordered': 8,
#  'bus': 8,
#  'subway': 8,
#  'attached': 8,
#  'standard': 8,
#  'level': 8,
#  'sound': 7,
#  'anywhere': 7,
#  'charge': 7,
#  'rd': 7,
#  'bars': 7,
#  'rush': 7,
#  'attentive': 7,
#  'makes': 7,
#  'same': 7,
#  'due': 7,
#  'store': 7,
#  'checking': 7,
#  'hotwire': 7,
#  'surprised': 7,
#  'entrance': 7,
#  'older': 7,
#  'added': 7,
#  'delivered': 7,
#  'daughter': 7,
#  'coast': 7,
#  'job': 7,
#  'order': 7,
#  'previous': 7,
#  'money': 7,
#  'request': 6,
#  'bathrooms': 6,
#  'chain': 6,
#  'under': 6,
#  'touch': 6,
#  'real': 6,
#  'wouldnt': 6,
#  'table': 6,
#  'charm': 6,
#  'surprise': 6,
#  'ride': 6,
#  'air': 6,
#  'pass': 6,
#  'his': 6,
#  'bother': 6,
#  'beat': 6,
#  'efficient': 6,
#  'st': 6,
#  'maker': 6,
#  'maid': 6,
#  'attractive': 6,
#  'expect': 6,
#  'why': 6,
#  'class': 6,
#  'problems': 6,
#  'boutique': 6,
#  'sitting': 6,
#  'told': 6,
#  'travelzoo': 6,
#  'outstanding': 6,
#  'website': 6,
#  'renovated': 6,
#  'busy': 6,
#  'minibar': 6,
#  'working': 6,
#  'second': 6,
#  'drake': 6,
#  'ok': 6,
#  'stop': 6,
#  'chocolate': 6,
#  'pm': 6,
#  'mini': 5,
#  'thru': 5,
#  'greeting': 5,
#  'oh': 5,
#  'start': 5,
#  'furniture': 5,
#  'history': 5,
#  'noisy': 5,
#  'minor': 5,
#  'hesitation': 5,
#  'heat': 5,
#  'keep': 5,
#  'ohare': 5,
#  'flowers': 5,
#  'tons': 5,
#  'institute': 5,
#  'shops': 5,
#  'live': 5,
#  'products': 5,
#  'fault': 5,
#  'boyfriend': 5,
#  'lady': 5,
#  'rest': 5,
#  'transportation': 5,
#  'traveler': 5,
#  'instead': 5,
#  'change': 5,
#  'members': 5,
#  'train': 5,
#  'finding': 5,
#  'turn': 5,
#  'doormen': 5,
#  'w': 5,
#  'prepared': 5,
#  'wall': 5,
#  'member': 5,
#  'beer': 5,
#  'window': 5,
#  'works': 5,
#  'put': 5,
#  'field': 5,
#  'stuff': 5,
#  'station': 5,
#  'cheap': 5,
#  'historic': 5,
#  'updated': 5,
#  'health': 5,
#  'trying': 5,
#  'elevators': 5,
#  'directions': 5,
#  'may': 5,
#  'based': 5,
#  'july': 5,
#  'compared': 5,
#  'eggs': 5,
#  'heard': 5,
#  'pricey': 5,
#  'couch': 5,
#  'juice': 5,
#  'aria': 5}

# %%
NP = sum([n for _,n in pos_count.items()])
NN = sum([n for _,n in neg_count.items()])
count_diff = {}
for t,n in pos_count.items():
    neg_n = neg_count.get(t, 1.0)
    count_diff[t] = math.log(n/NP) - math.log(neg_n/NN)
sorted_pos = sorted(count_diff.items(), key=lambda kv: kv[1], reverse=True)
sorted_pos
# Out:
# [('perfect', 4.8542380787924655),
#  ('spacious', 4.766130811282199),
#  ('enjoyed', 4.654905176171974),
#  ('fantastic', 4.347420476424014),
#  ('navy', 4.124276925109804),
#  ('atmosphere', 3.8693846754810144),
#  ('elegant', 3.7312343370001972),
#  ('fabulous', 3.7312343370001972),
#  ('flat', 3.69349400901735),
#  ('dining', 3.6542732958640682),
#  ('delicious', 3.6542732958640682),
#  ('gym', 3.6542732958640682),
#  ('pump', 3.6134513013438134),
#  ('professional', 3.5264399243541833),
#  ('awesome', 3.5264399243541833),
#  ('convenient', 3.5264399243541833),
#  ('gorgeous', 3.4799199087192907),
#  ('favorite', 3.4311297445498585),
#  ('incredible', 3.4311297445498585),
#  ('buffet', 3.4311297445498585),
#  ('future', 3.3798364501623084),
#  ('reasonable', 3.3257692288920326),
#  ('polite', 3.3257692288920326),
#  ('workout', 3.3257692288920326),
#  ('cozy', 3.3257692288920326),
#  ('minute', 3.3257692288920326),
#  ('helped', 3.2686108150520843),
#  ('feeling', 3.2686108150520843),
#  ('attractions', 3.2686108150520843),
#  ('pet', 3.1434476720980786),
#  ('indoor', 3.1434476720980786),
#  ('wireless', 3.1434476720980786),
#  ('living', 3.1434476720980786),
#  ('music', 3.1434476720980786),
#  ('comfy', 3.1434476720980786),
#  ('fast', 3.074454800611127),
#  ('welcoming', 3.074454800611127),
#  ('ipod', 3.074454800611127),
#  ('upscale', 3.074454800611127),
#  ('doorman', 3.0003468284574044),
#  ('loved', 2.947703094971983),
#  ('furnished', 2.920304120783868),
#  ('thanks', 2.920304120783868),
#  ('easily', 2.920304120783868),
#  ('rates', 2.920304120783868),
#  ('plasma', 2.920304120783868),
#  ('spotless', 2.920304120783868),
#  ('notch', 2.920304120783868),
#  ('accommodating', 2.920304120783868),
#  ('hancock', 2.920304120783868),
#  ('upgraded', 2.920304120783868),
#  ('wonderful', 2.920304120783867),
#  ('pets', 2.833292743794239),
#  ('gold', 2.833292743794239),
#  ('theres', 2.833292743794239),
#  ('safe', 2.833292743794239),
#  ('superb', 2.833292743794239),
#  ('separate', 2.833292743794239),
#  ('amazing', 2.8180252716634504),
#  ('beautifully', 2.737982563989913),
#  ('moment', 2.737982563989913),
#  ('comfort', 2.737982563989913),
#  ('john', 2.737982563989913),
#  ('neighborhood', 2.737982563989913),
#  ('mall', 2.737982563989913),
#  ('classy', 2.632622048332088),
#  ('lounge', 2.632622048332088),
#  ('massage', 2.632622048332088),
#  ('advantage', 2.632622048332088),
#  ('soft', 2.632622048332088),
#  ('loop', 2.632622048332088),
#  ('complaint', 2.632622048332088),
#  ('definately', 2.632622048332088),
#  ('tvs', 2.632622048332088),
#  ('excellent', 2.5807969804675013),
#  ('fit', 2.5148390126757043),
#  ('offers', 2.5148390126757043),
#  ('seeing', 2.5148390126757043),
#  ('pleasure', 2.5148390126757043),
#  ('aquarium', 2.5148390126757043),
#  ('appointed', 2.5148390126757043),
#  ('complaints', 2.5148390126757043),
#  ('terrific', 2.5148390126757043),
#  ('n', 2.5148390126757043),
#  ('program', 2.5148390126757043),
#  ('bus', 2.5148390126757043),
#  ('subway', 2.5148390126757043),
#  ('attached', 2.5148390126757043),
#  ('distance', 2.493785603477872),
#  ('pier', 2.489521204691415),
#  ('highly', 2.3970559770193196),
#  ('relaxed', 2.3813076200511816),
#  ('style', 2.3813076200511816),
#  ('local', 2.3813076200511816),
#  ('skyline', 2.3813076200511816),
#  ('neat', 2.3813076200511816),
#  ('enjoyable', 2.3813076200511816),
#  ('spectacular', 2.3813076200511816),
#  ('royalty', 2.3813076200511816),
#  ('anywhere', 2.3813076200511816),
#  ('rd', 2.3813076200511816),
#  ('rush', 2.3813076200511816),
#  ('attentive', 2.3813076200511816),
#  ('store', 2.3813076200511816),
#  ('hotwire', 2.3813076200511816),
#  ('added', 2.3813076200511816),
#  ('coast', 2.3813076200511816),
#  ('magnificent', 2.35232008317793),
#  ('beautiful', 2.2679789347441774),
#  ('screen', 2.2271569402239235),
#  ('breathtaking', 2.2271569402239226),
#  ('important', 2.2271569402239226),
#  ('worked', 2.2271569402239226),
#  ('definetly', 2.2271569402239226),
#  ('designed', 2.2271569402239226),
#  ('exceptional', 2.2271569402239226),
#  ('yours', 2.2271569402239226),
#  ('helping', 2.2271569402239226),
#  ('satisfied', 2.2271569402239226),
#  ('die', 2.2271569402239226),
#  ('whether', 2.2271569402239226),
#  ('wish', 2.2271569402239226),
#  ('conveniently', 2.2271569402239226),
#  ('pampered', 2.2271569402239226),
#  ('shedd', 2.2271569402239226),
#  ('equipped', 2.2271569402239226),
#  ('breath', 2.2271569402239226),
#  ('touch', 2.2271569402239226),
#  ('charm', 2.2271569402239226),
#  ('surprise', 2.2271569402239226),
#  ('pass', 2.2271569402239226),
#  ('efficient', 2.2271569402239226),
#  ('maker', 2.2271569402239226),
#  ('attractive', 2.2271569402239226),
#  ('boutique', 2.2271569402239226),
#  ('travelzoo', 2.2271569402239226),
#  ('outstanding', 2.2271569402239226),
#  ('drake', 2.2271569402239226),
#  ('chocolate', 2.2271569402239226),
#  ('ave', 2.2061035310260904),
#  ('easy', 2.1989860632572276),
#  ('comfortable', 2.051065933180605),
#  ('immaculate', 2.0448353834299677),
#  ('stepped', 2.0448353834299677),
#  ('married', 2.0448353834299677),
#  ('willing', 2.0448353834299677),
#  ('summer', 2.0448353834299677),
#  ('cocktail', 2.0448353834299677),
#  ('possible', 2.0448353834299677),
#  ('personally', 2.0448353834299677),
#  ('entertainment', 2.0448353834299677),
#  ('perfectly', 2.0448353834299677),
#  ('planning', 2.0448353834299677),
#  ('tour', 2.0448353834299677),
#  ('filled', 2.0448353834299677),
#  ('shop', 2.0448353834299677),
#  ('matter', 2.0448353834299677),
#  ('shulas', 2.0448353834299677),
#  ('inch', 2.0448353834299677),
#  ('heated', 2.0448353834299677),
#  ('greeting', 2.0448353834299677),
#  ('history', 2.0448353834299677),
#  ('minor', 2.0448353834299677),
#  ('hesitation', 2.0448353834299677),
#  ('heat', 2.0448353834299677),
#  ('ohare', 2.0448353834299677),
#  ('flowers', 2.0448353834299677),
#  ('tons', 2.0448353834299677),
#  ('institute', 2.0448353834299677),
#  ('shops', 2.0448353834299677),
#  ('products', 2.0448353834299677),
#  ('fault', 2.0448353834299677),
#  ('boyfriend', 2.0448353834299677),
#  ('transportation', 2.0448353834299677),
#  ('traveler', 2.0448353834299677),
#  ('members', 2.0448353834299677),
#  ('train', 2.0448353834299677),
#  ('doormen', 2.0448353834299677),
#  ('w', 2.0448353834299677),
#  ('prepared', 2.0448353834299677),
#  ('works', 2.0448353834299677),
#  ('field', 2.0448353834299677),
#  ('station', 2.0448353834299677),
#  ('historic', 2.0448353834299677),
#  ('updated', 2.0448353834299677),
#  ('health', 2.0448353834299677),
#  ('directions', 2.0448353834299677),
#  ('compared', 2.0448353834299677),
#  ('pricey', 2.0448353834299677),
#  ('couch', 2.0448353834299677),
#  ('juice', 2.0448353834299677),
#  ('aria', 2.0448353834299677),
#  ('michigan', 2.0342532740994317),
#  ('views', 2.0195175754456782),
#  ('lake', 1.9859948834070345),
#  ('blocks', 1.8823164539321935),
#  ('shopping', 1.8648640039809683),
#  ('decorated', 1.821691832115759),
#  ('pleased', 1.821691832115759),
#  ('mile', 1.7791322176969633),
#  ('lovely', 1.7791322176969633),
#  ('quick', 1.7346804551261288),
#  ('courteous', 1.716331316457933),
#  ('recommended', 1.716331316457933),
#  ('art', 1.716331316457933),
#  ('friendly', 1.7122579910702962),
#  ('restaurants', 1.699089510023427),
#  ('walking', 1.6965286891617533),
#  ('luxurious', 1.688160439491237),
#  ('everyone', 1.6640628879121762),
#  ('relaxing', 1.651792795320361),
#  ('definitely', 1.639370275321804),
#  ('fun', 1.6393702753218031),
#  ('helpful', 1.6140524673375145),
#  ('river', 1.5928502596869114),
#  ('modern', 1.5840201802386398),
#  ('great', 1.583823465376197),
#  ('avenue', 1.574831754184232),
#  ('quiet', 1.5340097596639781),
#  ('love', 1.5032381009972235),
#  ('within', 1.4813660261785557),
#  ('club', 1.4768513458240298),
#  ('happy', 1.446998382674347),
#  ('visit', 1.4360293513037732),
#  ('tower', 1.3909089160233048),
#  ('lots', 1.3227006659967708),
#  ('home', 1.3139478748871758),
#  ('fitness', 1.304435318019478),
#  ('kitchen', 1.2826953313830725),
#  ('city', 1.2826953313830716),
#  ('best', 1.2716454951964868),
#  ('meal', 1.2620760441803363),
#  ('heart', 1.2463276872121964),
#  ('huge', 1.2397702866660385),
#  ('concierge', 1.236175315748178),
#  ('traveling', 1.2238548313601392),
#  ('plenty', 1.2238548313601392),
#  ('ate', 1.2238548313601392),
#  ('eat', 1.20858735922935),
#  ('wine', 1.1975375230427652),
#  ('dinner', 1.1693666460760683),
#  ('always', 1.1520751489660075),
#  ('used', 0.09364817727381158),
#  ('take', 0.09245271986903703),
#  ('longer', 0.07872252705713656),
#  ('television', 0.07872252705713656),
#  ('older', 0.07872252705713656),
#  ('good', 0.07872252705713567),
#  ('early', 0.07249197730650003),
#  ('pillow', 0.06767269087055183),
#  ('were', 0.06665436084364984),
#  ('the', 0.06507145815434257),
#  ('as', 0.05674362033836111),
#  ('leave', 0.05240521873976256),
#  ('by', 0.047950868390381984),
#  ('was', 0.047753259457814945),
#  ('of', 0.045854315898289144),
#  ('wanted', 0.042354882886261436),
#  ('we', 0.03414999883190717),
#  ('ill', 0.0299323628877044),
#  ('arrival', 0.0299323628877044),
#  ('floor', 0.029932362887703512),
#  ('some', 0.026276051684592794),
#  ('experience', 0.026018463566567895),
#  ('hard', 0.023890048431741917),
#  ('too', 0.023890048431741917),
#  ('my', 0.021090572306243338),
#  ('king', 0.01923707377095596),
#  ('quite', 0.01850366706408124),
#  ('our', 0.015117277102563165),
#  ('want', 0.01418400591956459),
#  ('getting', 0.01418400591956459),
#  ('bed', 0.012837929528403791),
#  ('got', 0.012540620175834682),
#  ('both', 0.009313075684967309),
#  ('returned', 7.939973802351119e-05),
#  ('than', -0.003684247911280636),
#  ('space', -0.006435281283170724),
#  ('go', -0.014127626906327073),
#  ('life', -0.016587652747189097),
#  ('whole', -0.016587652747189097),
#  ('job', -0.016587652747189097),
#  ('looking', -0.018857801281728648),
#  ('in', -0.020104311641461425),
#  ('an', -0.021360931499846636),
#  ('week', -0.021360931499846636),
#  ('service', -0.026807465764048466),
#  ('like', -0.026943285504298586),
#  ('would', -0.028034393086633358),
#  ('days', -0.029965778693364697),
#  ('could', -0.03184499680854014),
#  ('entire', -0.03460615824986668),
#  ('pretty', -0.03460615824986757),
#  ('booking', -0.03460615824986846),
#  ('property', -0.03460615824986846),
#  ('thru', -0.03460615824986846),
#  ('eggs', -0.03460615824986846),
#  ('their', -0.04033683295885204),
#  ('have', -0.044827712321405144),
#  ('knew', -0.050110344785831984),
#  ('kind', -0.050110344785831984),
#  ('level', -0.050110344785831984),
#  ('street', -0.05707901410192662),
#  ('back', -0.06323287967630442),
#  ('extra', -0.06669447280136787),
#  ('i', -0.07132659833196886),
#  ('im', -0.07542815277012238),
#  ('know', -0.07542815277012238),
#  ('spent', -0.07542815277012238),
#  ('immediately', -0.07542815277012238),
#  ('site', -0.07542815277012238),
#  ('taking', -0.07542815277012238),
#  ('real', -0.07542815277012238),
#  ('anything', -0.08339632241929973),
#  ('made', -0.08408621551323758),
#  ('lobby', -0.0844779882900406),
#  ('tub', -0.08785067276867942),
#  ('less', -0.09069562490091165),
#  ('getaway', -0.09523078006630215),
#  ('parking', -0.09740705948889783),
#  ('only', -0.09762886275031502),
#  ('much', -0.10218560193967097),
#  ('recent', -0.10359902973681834),
#  ('per', -0.10359902973681834),
#  ('surprised', -0.10359902973681834),
#  ('bathroom', -0.1057335022654513),
#  ('night', -0.10848901503101072),
#  ('for', -0.1117957969409975),
#  ('conference', -0.1166711113041714),
#  ('decided', -0.12421831693955454),
#  ('show', -0.12421831693955454),
#  ('since', -0.12421831693955543),
#  ('if', -0.12532512391474526),
#  ('first', -0.12991633805419234),
#  ('being', -0.1363888525598096),
#  ('last', -0.1379485097514559),
#  ('around', -0.14442102425707404),
#  ('four', -0.14442102425707404),
#  ('staying', -0.15032946094324018),
#  ('say', -0.1523891939062505),
#  ('bring', -0.1523891939062505),
#  ('youre', -0.1523891939062505),
#  ('end', -0.1523891939062505),
#  ('it', -0.15516807620264128),
#  ('give', -0.15766625100709497),
#  ('conrad', -0.15930963675082488),
#  ('or', -0.16401723190136952),
#  ('quality', -0.17073833257444715),
#  ('experienced', -0.17073833257444804),
#  ('ride', -0.17073833257444804),
#  ('new', -0.17436810062502683),
#  ('expensive', -0.1777070018905409),
#  ('day', -0.18019147521820322),
#  ('to', -0.1822949358599768),
#  ('personal', -0.18364173741035472),
#  ('daughter', -0.18364173741035472),
#  ('done', -0.18875683807712473),
#  ('on', -0.19774634359189758),
#  ('more', -0.19910098248256958),
#  ('way', -0.20426102461309092),
#  ('think', -0.20815276842470443),
#  ('kept', -0.21122969392918378),
#  ('having', -0.21329794699324278),
#  ('completely', -0.21519009514528165),
#  ('there', -0.21570147332057843),
#  ('room', -0.21797424984639857),
#  ('book', -0.22138206539320215),
#  ('make', -0.2230641515761871),
#  ('special', -0.22384815788839507),
#  ('us', -0.22649716605997305),
#  ('how', -0.22957883259738043),
#  ('going', -0.23108146248191552),
#  ('part', -0.23365215798501726),
#  ('look', -0.23577080284530183),
#  ('am', -0.23713042236134196),
#  ('other', -0.24293462377893693),
#  ('upon', -0.2577497095640773),
#  ('believe', -0.2577497095640773),
#  ('beyond', -0.2577497095640773),
#  ('quickly', -0.2577497095640773),
#  ('inside', -0.2577497095640773),
#  ('provide', -0.2577497095640773),
#  ('mind', -0.2577497095640773),
#  ('although', -0.2577497095640773),
#  ('years', -0.2577497095640773),
#  ('airport', -0.2577497095640773),
#  ('sound', -0.2577497095640773),
#  ('mini', -0.2577497095640773),
#  ('one', -0.261122394042717),
#  ('out', -0.2616483499797342),
#  ('two', -0.2656548890711905),
#  ('about', -0.2719343445560334),
#  ('shower', -0.2719343445560334),
#  ('things', -0.28128020697427125),
#  ('offer', -0.28514868375219127),
#  ('price', -0.29053953238706764),
#  ('offered', -0.29284102937534673),
#  ('had', -0.29294395768587034),
#  ('making', -0.2954900375469247),
#  ('tired', -0.3022014721349109),
#  ('even', -0.305504140859977),
#  ('upgrade', -0.31837433138051097),
#  ('outside', -0.31837433138051185),
#  ('what', -0.3231324688269295),
#  ('received', -0.33185768171779895),
#  ('booked', -0.33428978668641207),
#  ('evening', -0.33779241723761366),
#  ('maid', -0.33779241723761366),
#  ('guests', -0.3463031069055216),
#  ('positive', -0.35305988936840293),
#  ('name', -0.35305988936840293),
#  ('yet', -0.3631102252219023),
#  ('find', -0.36311022522190317),
#  ('who', -0.36311022522190317),
#  ('far', -0.36311022522190317),
#  ('get', -0.3669490015290693),
#  ('services', -0.3755327452204593),
#  ('ask', -0.3755327452204611),
#  ('valet', -0.3755327452204611),
#  ('any', -0.3855830810739622),
#  ('reservations', -0.39128110218859913),
#  ('be', -0.4017559403195632),
#  ('though', -0.4067852887245653),
#  ('work', -0.4080319126134153),
#  ('found', -0.41190038939133533),
#  ('queen', -0.4119003893913362),
#  ('complete', -0.4119003893913362),
#  ('busy', -0.4119003893913362),
#  ('stop', -0.4119003893913362),
#  ('because', -0.41431877025561636),
#  ('but', -0.4193609691896425),
#  ('customer', -0.4248037942272438),
#  ('however', -0.42764874635947425),
#  ('fact', -0.42959996649073595),
#  ('live', -0.4400712663580322),
#  ('before', -0.4519057240050337),
#  ('me', -0.4535730857919029),
#  ('checkin', -0.4555754528939966),
#  ('thought', -0.45842040502622794),
#  ('construction', -0.4653890743423217),
#  ('person', -0.4690588032312837),
#  ('do', -0.4808932608782861),
#  ('small', -0.480893260878287),
#  ('bags', -0.4808932608782879),
#  ('prices', -0.4808932608782879),
#  ('minibar', -0.4808932608782879),
#  ('that', -0.49188238245388227),
#  ('morning', -0.5000631769860071),
#  ('care', -0.5028721675970615),
#  ('several', -0.5028721675970624),
#  ('still', -0.5046097874956033),
#  ('into', -0.509064137844983),
#  ('now', -0.509064137844983),
#  ('noisy', -0.5201139740315686),
#  ('forward', -0.5296834250477183),
#  ('side', -0.5296834250477183),
#  ('ordered', -0.5296834250477183),
#  ('better', -0.5370635323453419),
#  ('check', -0.5396008617050656),
#  ('long', -0.540612495579909),
#  ('thing', -0.5454317820158581),
#  ('delivered', -0.5631313591152587),
#  ('order', -0.5631313591152587),
#  ('use', -0.5631313591152596),
#  ('soon', -0.5762034406826118),
#  ('people', -0.5815367866579741),
#  ('they', -0.5840098815754411),
#  ('double', -0.5942219461852902),
#  ('checkout', -0.5942219461852911),
#  ('flight', -0.5942219461852911),
#  ('oh', -0.5942219461852911),
#  ('keep', -0.5942219461852911),
#  ('stuff', -0.5942219461852911),
#  ('help', -0.5986762965346699),
#  ('off', -0.5986762965346708),
#  ('over', -0.6015212486669013),
#  ('left', -0.6105710841868195),
#  ('actually', -0.6105710841868195),
#  ('full', -0.6105710841868195),
#  ('due', -0.6144246535028088),
#  ('expectations', -0.6206552032534454),
#  ('desk', -0.6232094830585417),
#  ('front', -0.6272212150243366),
#  ('car', -0.6324431590054873),
#  ('wifi', -0.6372393312689812),
#  ('open', -0.6372393312689812),
#  ('checked', -0.6382135154668243),
#  ('door', -0.6407419618201828),
#  ('available', -0.6455152405728404),
#  ('when', -0.6497010985055187),
#  ('chose', -0.663214817672241),
#  ('did', -0.6772402930267463),
#  ('sleep', -0.6851937243910164),
#  ('water', -0.6885326256565314),
#  ('wait', -0.6906137918603559),
#  ('least', -0.6906137918603559),
#  ('let', -0.6930677808219228),
#  ('does', -0.6930677808219228),
#  ('took', -0.6949635159868217),
#  ('system', -0.7172820389425176),
#  ('then', -0.7257351746535754),
#  ('after', -0.7260157189112713),
#  ('he', -0.7262277855009751),
#  ('doors', -0.7277533388098139),
#  ('change', -0.7277533388098139),
#  ('up', -0.7319579700918446),
#  ('reception', -0.7432575253457774),
#  ('been', -0.7608532872361575),
#  ('hilton', -0.7685753333300669),
#  ('saw', -0.7685753333300669),
#  ('request', -0.7685753333300678),
#  ('never', -0.7818205600800887),
#  ('else', -0.7838428054608562),
#  ('lady', -0.7883779606262475),
#  ('problem', -0.7932679459204399),
#  ('not', -0.8080668657131689),
#  ('went', -0.8089266288536345),
#  ('down', -0.8132755122479747),
#  ('coming', -0.817365497499499),
#  ('might', -0.817365497499499),
#  ('cost', -0.817365497499499),
#  ('came', -0.8235574677474204),
#  ('almost', -0.8302689023354075),
#  ('asked', -0.832035687247294),
#  ('rest', -0.8455363744661959),
#  ('she', -0.8512670491751813),
#  ('star', -0.8708541824504863),
#  ('times', -0.8708541824504863),
#  ('arrived', -0.881904018637071),
#  ('hear', -0.8863583689864507),
#  ('housekeeping', -0.8937384762840734),
#  ('start', -0.8996035957364725),
#  ('turn', -0.8996035957364725),
#  ('these', -0.9043768744891292),
#  ('should', -0.9083372757052262),
#  ('ok', -0.908337275705227),
#  ('paid', -0.9145292459531476),
#  ('hot', -0.9298434809261904),
#  ('towels', -0.9340897718076402),
#  ('gave', -0.9508968901240218),
#  ('late', -0.9755895027143948),
#  ('old', -0.9886372181068701),
#  ('why', -0.9917188846442784),
#  ('window', -0.9996870542934548),
#  ('cheap', -0.9996870542934548),
#  ('elevator', -1.0049641113942975),
#  ('once', -1.0069863567750659),
#  ('try', -1.0115215119404573),
#  ('no', -1.0288584315937346),
#  ('noise', -1.030939597797559),
#  ('trying', -1.0462070699283483),
#  ('requested', -1.0562574057818477),
#  ('working', -1.0686799257804065),
#  ('spend', -1.0844282827485445),
#  ('ready', -1.090658832499182),
#  ('brought', -1.1332184469179776),
#  ('point', -1.1332184469179776),
#  ('him', -1.140138889762551),
#  ('online', -1.140138889762551),
#  ('another', -1.1476071843700764),
#  ('given', -1.1556913027700357),
#  ('looked', -1.1740404414382315),
#  ('set', -1.1740404414382333),
#  ('line', -1.1987330540286036),
#  ('wouldnt', -1.2068302642612236),
#  ('furniture', -1.213261154591514),
#  ('may', -1.213261154591514),
#  ('her', -1.2337596761398544),
#  ('call', -1.2430333129251832),
#  ('above', -1.2510014825743614),
#  ('wall', -1.2510014825743614),
#  ('same', -1.256278539675204),
#  ('checking', -1.256278539675204),
#  ('wasnt', -1.257921925418934),
#  ('heard', -1.2873691267452356),
#  ('them', -1.2918234770946162),
#  ('under', -1.299203584392239),
#  ('pay', -1.3050687038446371),
#  ('tell', -1.322460446556506),
#  ('second', -1.3563619982321873),
#  ('instead', -1.3563619982321873),
#  ('nothing', -1.3681964558791888),
#  ('phone', -1.397183992752442),
#  ('seemed', -1.402882013867079),
#  ('expect', -1.410429219502463),
#  ('website', -1.410429219502463),
#  ('problems', -1.4364047059057237),
#  ('air', -1.4617225138900132),
#  ('expected', -1.4688399816588769),
#  ('elevators', -1.4815251411861938),
#  ('hours', -1.4898933908567091),
#  ('his', -1.579505549546397),
#  ('put', -1.592750776296418),
#  ('pm', -1.6229906614861358),
#  ('charge', -1.6260255651812887),
#  ('something', -1.6646633578867043),
#  ('reservation', -1.6817843986668155),
#  ('hour', -1.7046686925004026),
#  ('said', -1.720584147806302),
#  ('bad', -1.7240867783575036),
#  ('until', -1.8869902492943575),
#  ('money', -1.9091518210972094),
#  ('minutes', -2.0678583174603276),
#  ('called', -2.1746723217461383),
#  ('told', -2.7495768021966516)]

# %%
count_diff_neg = {}
for t,n in neg_count.items():
    pos_n = pos_count.get(t, 1.0)
    count_diff_neg[t] = -math.log(pos_n/NP) + math.log(n/NN)
sorted_neg = sorted(count_diff_neg.items(), key=lambda kv: kv[1], reverse=True)
sorted_neg
# Out:
# [('finally', 4.255950411233275),
#  ('rude', 4.041939343482338),
#  ('disappointed', 3.882090642540442),
#  ('someone', 3.6421399729098507),
#  ('manager', 3.6421399729098507),
#  ('dirty', 3.625045539550551),
#  ('worst', 3.5348944425562534),
#  ('clerk', 3.496428161728457),
#  ('later', 3.456422827114759),
#  ('smelled', 3.4147501307141903),
#  ('cold', 3.3487921629223925),
#  ('smell', 3.325802644697694),
#  ('toilet', 3.325802644697694),
#  ('waiting', 3.27817459570844),
#  ('cleaned', 3.228164175133778),
#  ('sheets', 3.228164175133778),
#  ('carpet', 3.228164175133778),
#  ('smoke', 3.2021886887305175),
#  ('walls', 3.175520441648356),
#  ('card', 3.175520441648356),
#  ('unfortunately', 3.148121467460242),
#  ('slow', 3.148121467460242),
#  ('either', 3.119950590493545),
#  ('terrible', 3.0909630536202934),
#  ('poor', 3.0909630536202934),
#  ('wrong', 3.0611100904706117),
#  ('loud', 3.030338431803858),
#  ('tried', 3.030338431803858),
#  ('despite', 3.030338431803858),
#  ('charged', 3.030338431803858),
#  ('rather', 2.998589733489278),
#  ('supposed', 2.998589733489278),
#  ('key', 2.998589733489278),
#  ('broken', 2.998589733489278),
#  ('smoking', 2.965799910666287),
#  ('seems', 2.9318983589906056),
#  ('credit', 2.9318983589906056),
#  ('hallway', 2.8968070391793352),
#  ('already', 2.8968070391793352),
#  ('cleaning', 2.860439395008461),
#  ('reserved', 2.860439395008461),
#  ('ended', 2.860439395008461),
#  ('average', 2.860439395008461),
#  ('overpriced', 2.860439395008461),
#  ('luggage', 2.8226990670256136),
#  ('half', 2.8226990670256136),
#  ('mistake', 2.8226990670256136),
#  ('issue', 2.8226990670256136),
#  ('complain', 2.783478353872333),
#  ('management', 2.783478353872333),
#  ('uncomfortable', 2.783478353872333),
#  ('told', 2.7495768021966516),
#  ('guess', 2.742656359352077),
#  ('move', 2.742656359352077),
#  ('fix', 2.7000967449332816),
#  ('woman', 2.7000967449332816),
#  ('turned', 2.655644982362448),
#  ('behind', 2.655644982362448),
#  ('waited', 2.655644982362448),
#  ('bill', 2.655644982362448),
#  ('worse', 2.6091249667275545),
#  ('party', 2.6091249667275545),
#  ('elsewhere', 2.6091249667275545),
#  ('light', 2.6091249667275545),
#  ('using', 2.6091249667275545),
#  ('werent', 2.6091249667275545),
#  ('sent', 2.6091249667275545),
#  ('paying', 2.6091249667275545),
#  ('past', 2.6091249667275545),
#  ('twice', 2.6091249667275545),
#  ('downstairs', 2.6091249667275545),
#  ('somewhere', 2.5603348025581223),
#  ('hair', 2.5603348025581223),
#  ('expecting', 2.5603348025581223),
#  ('obviously', 2.5603348025581223),
#  ('ridiculous', 2.5603348025581223),
#  ('moved', 2.5603348025581223),
#  ('seem', 2.5603348025581223),
#  ('paper', 2.5603348025581223),
#  ('general', 2.5603348025581223),
#  ('maybe', 2.5603348025581223),
#  ('nonsmoking', 2.509041508170572),
#  ('certainly', 2.509041508170572),
#  ('horrible', 2.509041508170572),
#  ('sign', 2.509041508170572),
#  ('changed', 2.509041508170572),
#  ('apparently', 2.509041508170572),
#  ('convention', 2.509041508170572),
#  ('options', 2.509041508170572),
#  ('avoid', 2.509041508170572),
#  ('decent', 2.509041508170572),
#  ('employee', 2.509041508170572),
#  ('nor', 2.509041508170572),
#  ('worn', 2.509041508170572),
#  ('tiny', 2.509041508170572),
#  ('computer', 2.4549742869002955),
#  ('started', 2.4549742869002955),
#  ('promised', 2.4549742869002955),
#  ('sink', 2.4549742869002955),
#  ('nobody', 2.4549742869002955),
#  ('arriving', 2.4549742869002955),
#  ('situation', 2.4549742869002955),
#  ('calls', 2.4549742869002955),
#  ('lack', 2.4549742869002955),
#  ('issues', 2.4549742869002955),
#  ('main', 2.4549742869002955),
#  ('clearly', 2.4549742869002955),
#  ('sort', 2.397815873060347),
#  ('needless', 2.397815873060347),
#  ('amount', 2.397815873060347),
#  ('confirmation', 2.397815873060347),
#  ('difficult', 2.397815873060347),
#  ('thin', 2.397815873060347),
#  ('throughout', 2.397815873060347),
#  ('inn', 2.397815873060347),
#  ('disappointing', 2.397815873060347),
#  ('woke', 2.397815873060347),
#  ('happened', 2.397815873060347),
#  ('talking', 2.3371912512439135),
#  ('fee', 2.3371912512439135),
#  ('discount', 2.3371912512439135),
#  ('noticed', 2.3371912512439135),
#  ('attitude', 2.3371912512439135),
#  ('awful', 2.3371912512439135),
#  ('stains', 2.3371912512439135),
#  ('stained', 2.3371912512439135),
#  ('switch', 2.3371912512439135),
#  ('appeared', 2.3371912512439135),
#  ('case', 2.3371912512439135),
#  ('opened', 2.3371912512439135),
#  ('course', 2.3371912512439135),
#  ('between', 2.3371912512439135),
#  ('counter', 2.2726527301063424),
#  ('girl', 2.2726527301063424),
#  ('mediocre', 2.2726527301063424),
#  ('discovered', 2.2726527301063424),
#  ('complained', 2.2726527301063424),
#  ('refused', 2.2726527301063424),
#  ('experiences', 2.2726527301063424),
#  ('smaller', 2.2726527301063424),
#  ('unpleasant', 2.2726527301063424),
#  ('disappointment', 2.2726527301063424),
#  ('doing', 2.2726527301063424),
#  ('asking', 2.2726527301063424),
#  ('guy', 2.2726527301063424),
#  ('unless', 2.2726527301063424),
#  ('receptionist', 2.2726527301063424),
#  ('maintenance', 2.2726527301063424),
#  ('closed', 2.2726527301063424),
#  ('correct', 2.2726527301063424),
#  ('renovation', 2.2726527301063424),
#  ('security', 2.2726527301063424),
#  ('odor', 2.2036598586193907),
#  ('motel', 2.2036598586193907),
#  ('idea', 2.2036598586193907),
#  ('barely', 2.2036598586193907),
#  ('trouble', 2.2036598586193907),
#  ('leaving', 2.2036598586193907),
#  ('hand', 2.2036598586193907),
#  ('lost', 2.2036598586193907),
#  ('items', 2.2036598586193907),
#  ('mold', 2.2036598586193907),
#  ('running', 2.2036598586193907),
#  ('man', 2.2036598586193907),
#  ('white', 2.2036598586193907),
#  ('review', 2.2036598586193907),
#  ('floors', 2.2036598586193907),
#  ('ice', 2.2036598586193907),
#  ('called', 2.1746723217461383),
#  ('musty', 2.129551886465668),
#  ('traffic', 2.129551886465668),
#  ('nearly', 2.129551886465668),
#  ('attention', 2.129551886465668),
#  ('afternoon', 2.129551886465668),
#  ('filthy', 2.129551886465668),
#  ('process', 2.129551886465668),
#  ('planned', 2.129551886465668),
#  ('tip', 2.129551886465668),
#  ('reason', 2.129551886465668),
#  ('soap', 2.129551886465668),
#  ('failed', 2.129551886465668),
#  ('annoyed', 2.129551886465668),
#  ('send', 2.129551886465668),
#  ('carpets', 2.129551886465668),
#  ('sit', 2.129551886465668),
#  ('charges', 2.129551886465668),
#  ('hallways', 2.129551886465668),
#  ('dark', 2.129551886465668),
#  ('policy', 2.129551886465668),
#  ('chair', 2.129551886465668),
#  ('minutes', 2.0678583174603276),
#  ('excited', 2.049509178792132),
#  ('assured', 2.049509178792132),
#  ('boy', 2.049509178792132),
#  ('apology', 2.049509178792132),
#  ('dingy', 2.049509178792132),
#  ('customers', 2.049509178792132),
#  ('bugs', 2.049509178792132),
#  ('anyway', 2.049509178792132),
#  ('poorly', 2.049509178792132),
#  ('lacking', 2.049509178792132),
#  ('shampoo', 2.049509178792132),
#  ('inconvenience', 2.049509178792132),
#  ('comes', 2.049509178792132),
#  ('please', 2.049509178792132),
#  ('group', 2.049509178792132),
#  ('advance', 2.049509178792132),
#  ('red', 2.049509178792132),
#  ('cigarette', 1.9624978018025026),
#  ('originally', 1.9624978018025026),
#  ('cleanliness', 1.9624978018025026),
#  ('pictures', 1.9624978018025026),
#  ('children', 1.9624978018025026),
#  ('informed', 1.9624978018025026),
#  ('months', 1.9624978018025026),
#  ('sat', 1.9624978018025026),
#  ('list', 1.9624978018025026),
#  ('mattress', 1.9624978018025026),
#  ('unable', 1.9624978018025026),
#  ('ran', 1.9624978018025026),
#  ('ten', 1.9624978018025026),
#  ('higher', 1.9624978018025026),
#  ('glasses', 1.9624978018025026),
#  ('dollars', 1.9624978018025026),
#  ('sleeper', 1.9624978018025026),
#  ('totally', 1.9624978018025026),
#  ('covered', 1.9624978018025026),
#  ('aware', 1.9624978018025026),
#  ('run', 1.9624978018025026),
#  ('fridge', 1.9624978018025026),
#  ('money', 1.9091518210972094),
#  ('until', 1.8869902492943575),
#  ('min', 1.3563619982321864),
#  ('wallpaper', 1.3563619982321864),
#  ('ones', 1.3563619982321864),
#  ('house', 1.3563619982321864),
#  ('simple', 1.3563619982321864),
#  ('weak', 1.3563619982321864),
#  ('handle', 1.3563619982321864),
#  ('talk', 1.3563619982321864),
#  ('leaked', 1.3563619982321864),
#  ('cell', 1.3563619982321864),
#  ('impossible', 1.3563619982321864),
#  ('chosen', 1.3563619982321864),
#  ('saturday', 1.3563619982321864),
#  ('generally', 1.3563619982321864),
#  ('response', 1.3563619982321864),
#  ('lets', 1.3563619982321864),
#  ('break', 1.3563619982321864),
#  ('costs', 1.3563619982321864),
#  ('rating', 1.3563619982321864),
#  ('answer', 1.3563619982321864),
#  ('apologize', 1.3563619982321864),
#  ('currently', 1.3563619982321864),
#  ('peninsula', 1.3563619982321864),
#  ('tile', 1.3563619982321864),
#  ('mattresses', 1.3563619982321864),
#  ('shocked', 1.3563619982321864),
#  ('opinion', 1.3563619982321864),
#  ('realized', 1.3563619982321864),
#  ('telling', 1.3563619982321864),
#  ('swim', 1.3563619982321864),
#  ('emergency', 1.3563619982321864),
#  ('tell', 1.322460446556506),
#  ('pay', 1.3050687038446371),
#  ('under', 1.299203584392239),
#  ('them', 1.2918234770946162),
#  ('heard', 1.2873691267452356),
#  ('wasnt', 1.257921925418934),
#  ('checking', 1.256278539675204),
#  ('same', 1.256278539675204),
#  ('wall', 1.2510014825743614),
#  ('above', 1.2510014825743614),
#  ('call', 1.2430333129251832),
#  ('her', 1.2337596761398544),
#  ('furniture', 1.213261154591514),
#  ('may', 1.213261154591514),
#  ('wouldnt', 1.2068302642612236),
#  ('line', 1.1987330540286036),
#  ('set', 1.1740404414382333),
#  ('looked', 1.1740404414382315),
#  ('carry', 1.1740404414382315),
#  ('showed', 1.1740404414382315),
#  ('lukewarm', 1.1740404414382315),
#  ('laptop', 1.1740404414382315),
#  ('wet', 1.1740404414382315),
#  ('pressure', 1.1740404414382315),
#  ('office', 1.1740404414382315),
#  ('eye', 1.1740404414382315),
#  ('suppose', 1.1740404414382315),
#  ('favor', 1.1740404414382315),
#  ('college', 1.1740404414382315),
#  ('stain', 1.1740404414382315),
#  ('hassle', 1.1740404414382315),
#  ('allowed', 1.1740404414382315),
#  ('settled', 1.1740404414382315),
#  ('leg', 1.1740404414382315),
#  ('relatively', 1.1740404414382315),
#  ('ahead', 1.1740404414382315),
#  ('theyre', 1.1740404414382315),
#  ('insisted', 1.1740404414382315),
#  ('burnt', 1.1740404414382315),
#  ('shown', 1.1740404414382315),
#  ('continental', 1.1740404414382315),
#  ('turns', 1.1740404414382315),
#  ('allow', 1.1740404414382315),
#  ('notice', 1.1740404414382315),
#  ('packed', 1.1740404414382315),
#  ('usually', 1.1740404414382315),
#  ('connection', 1.1740404414382315),
#  ('subpar', 1.1740404414382315),
#  ('month', 1.1740404414382315),
#  ('drip', 1.1740404414382315),
#  ('maintained', 1.1740404414382315),
#  ('cannot', 1.1740404414382315),
#  ('agreed', 1.1740404414382315),
#  ('together', 1.1740404414382315),
#  ('managed', 1.1740404414382315),
#  ('dissatisfied', 1.1740404414382315),
#  ('apologies', 1.1740404414382315),
#  ('addition', 1.1740404414382315),
#  ('doubt', 1.1740404414382315),
#  ('compensation', 1.1740404414382315),
#  ('yellow', 1.1740404414382315),
#  ('hardly', 1.1740404414382315),
#  ('superior', 1.1740404414382315),
#  ('deluxe', 1.1740404414382315),
#  ('non', 1.1740404414382315),
#  ('gross', 1.1740404414382315),
#  ('crowded', 1.1740404414382315),
#  ('stopped', 1.1740404414382315),
#  ('cheese', 1.1740404414382315),
#  ('knock', 1.1740404414382315),
#  ('champagne', 1.1740404414382315),
#  ('al', 1.1740404414382315),
#  ('movie', 1.1740404414382315),
#  ('midnight', 1.1740404414382315),
#  ('temperature', 1.1740404414382315),
#  ('actual', 1.1740404414382315),
#  ('chicken', 1.1740404414382315),
#  ('hospitality', 1.1740404414382315),
#  ('placed', 1.1740404414382315),
#  ('removed', 1.1740404414382315),
#  ('attempted', 1.1740404414382315),
#  ('number', 1.1740404414382315),
#  ('giving', 1.1740404414382315),
#  ('recommendations', 1.1740404414382315),
#  ('figure', 1.1740404414382315),
#  ('bug', 1.1740404414382315),
#  ('cramped', 1.1740404414382315),
#  ('remember', 1.1740404414382315),
#  ('hrs', 1.1740404414382315),
#  ('resolve', 1.1740404414382315),
#  ('receive', 1.1740404414382315),
#  ('training', 1.1740404414382315),
#  ('cafe', 1.1740404414382315),
#  ('hrh', 1.1740404414382315),
#  ('rooftop', 1.1740404414382315),
#  ('throw', 1.1740404414382315),
#  ('normal', 1.1740404414382315),
#  ('upset', 1.1740404414382315),
#  ('peeling', 1.1740404414382315),
#  ('stops', 1.1740404414382315),
#  ('machines', 1.1740404414382315),
#  ('phones', 1.1740404414382315),
#  ('picture', 1.1740404414382315),
#  ('hanging', 1.1740404414382315),
#  ('deliver', 1.1740404414382315),
#  ('brother', 1.1740404414382315),
#  ('lying', 1.1740404414382315),
#  ('workers', 1.1740404414382315),
#  ('stated', 1.1740404414382315),
#  ('bottom', 1.1740404414382315),
#  ('fitzpatrick', 1.1740404414382315),
#  ('overnight', 1.1740404414382315),
#  ('discover', 1.1740404414382315),
#  ('frequently', 1.1740404414382315),
#  ('hospital', 1.1740404414382315),
#  ('roof', 1.1740404414382315),
#  ('luck', 1.1740404414382315),
#  ('sell', 1.1740404414382315),
#  ('photos', 1.1740404414382315),
#  ('okay', 1.1740404414382315),
#  ('stand', 1.1740404414382315),
#  ('temp', 1.1740404414382315),
#  ('preferred', 1.1740404414382315),
#  ('westin', 1.1740404414382315),
#  ('fixed', 1.1740404414382315),
#  ('cut', 1.1740404414382315),
#  ('stuck', 1.1740404414382315),
#  ('fees', 1.1740404414382315),
#  ('third', 1.1740404414382315),
#  ('bites', 1.1740404414382315),
#  ('yourself', 1.1740404414382315),
#  ('closer', 1.1740404414382315),
#  ('glad', 1.1740404414382315),
#  ('given', 1.1556913027700357),
#  ('another', 1.1476071843700764),
#  ('stuff', 0.5942219461852911),
#  ('keep', 0.5942219461852911),
#  ('checkout', 0.5942219461852911),
#  ('oh', 0.5942219461852911),
#  ('double', 0.5942219461852902),
#  ('they', 0.5840098815754411),
#  ('people', 0.5815367866579741),
#  ('soon', 0.5762034406826118),
#  ('use', 0.5631313591152596),
#  ('order', 0.5631313591152587),
#  ('delivered', 0.5631313591152587),
#  ('thing', 0.5454317820158581),
#  ('long', 0.540612495579909),
#  ('check', 0.5396008617050656),
#  ('better', 0.5370635323453419),
#  ('ordered', 0.5296834250477183),
#  ('forward', 0.5296834250477183),
#  ('side', 0.5296834250477183),
#  ('noisy', 0.5201139740315686),
#  ('into', 0.509064137844983),
#  ('now', 0.509064137844983),
#  ('still', 0.5046097874956033),
#  ('several', 0.5028721675970624),
#  ('care', 0.5028721675970615),
#  ('morning', 0.5000631769860071),
#  ('that', 0.49188238245388227),
#  ('bags', 0.4808932608782879),
#  ('prices', 0.4808932608782879),
#  ('minibar', 0.4808932608782879),
#  ('small', 0.480893260878287),
#  ('do', 0.4808932608782861),
#  ('person', 0.4690588032312837),
#  ('construction', 0.4653890743423217),
#  ('thought', 0.45842040502622794),
#  ('checkin', 0.4555754528939966),
#  ('me', 0.4535730857919029),
#  ('before', 0.4519057240050337),
#  ('live', 0.4400712663580322),
#  ('fact', 0.42959996649073595),
#  ('however', 0.42764874635947425),
#  ('customer', 0.4248037942272438),
#  ('but', 0.4193609691896425),
#  ('because', 0.41431877025561636),
#  ('queen', 0.4119003893913362),
#  ('busy', 0.4119003893913362),
#  ('stop', 0.4119003893913362),
#  ('complete', 0.4119003893913362),
#  ('found', 0.41190038939133533),
#  ('work', 0.4080319126134153),
#  ('though', 0.4067852887245653),
#  ('be', 0.4017559403195632),
#  ('reservations', 0.39128110218859913),
#  ('any', 0.3855830810739622),
#  ('valet', 0.3755327452204611),
#  ('ask', 0.3755327452204611),
#  ('services', 0.3755327452204593),
#  ('get', 0.3669490015290693),
#  ('find', 0.36311022522190317),
#  ('who', 0.36311022522190317),
#  ('far', 0.36311022522190317),
#  ('yet', 0.3631102252219023),
#  ('name', 0.35305988936840293),
#  ('positive', 0.35305988936840293),
#  ('guests', 0.3463031069055216),
#  ('maid', 0.33779241723761366),
#  ('evening', 0.33779241723761366),
#  ('booked', 0.33428978668641207),
#  ('received', 0.33185768171779895),
#  ('what', 0.3231324688269295),
#  ('outside', 0.31837433138051185),
#  ('upgrade', 0.31837433138051097),
#  ('even', 0.305504140859977),
#  ('tired', 0.3022014721349109),
#  ('making', 0.2954900375469247),
#  ('had', 0.29294395768587034),
#  ('offered', 0.29284102937534673),
#  ('price', 0.29053953238706764),
#  ('offer', 0.28514868375219127),
#  ('things', 0.28128020697427125),
#  ('about', 0.2719343445560334),
#  ('shower', 0.2719343445560334),
#  ('two', 0.2656548890711905),
#  ('out', 0.2616483499797342),
#  ('one', 0.261122394042717),
#  ('upon', 0.2577497095640773),
#  ('although', 0.2577497095640773),
#  ('inside', 0.2577497095640773),
#  ('believe', 0.2577497095640773),
#  ('provide', 0.2577497095640773),
#  ('beyond', 0.2577497095640773),
#  ('airport', 0.2577497095640773),
#  ('sound', 0.2577497095640773),
#  ('quickly', 0.2577497095640773),
#  ('years', 0.2577497095640773),
#  ('mind', 0.2577497095640773),
#  ('mini', 0.2577497095640773),
#  ('other', 0.24293462377893693),
#  ('am', 0.23713042236134196),
#  ('look', 0.23577080284530183),
#  ('part', 0.23365215798501726),
#  ('going', 0.23108146248191552),
#  ('how', 0.22957883259738043),
#  ('us', 0.22649716605997305),
#  ('special', 0.22384815788839507),
#  ('make', 0.2230641515761871),
#  ('book', 0.22138206539320215),
#  ('room', 0.21797424984639857),
#  ('there', 0.21570147332057843),
#  ('completely', 0.21519009514528165),
#  ('having', 0.21329794699324278),
#  ('kept', 0.21122969392918378),
#  ('think', 0.20815276842470443),
#  ('way', 0.20426102461309092),
#  ('more', 0.19910098248256958),
#  ('on', 0.19774634359189758),
#  ('done', 0.18875683807712473),
#  ('personal', 0.18364173741035472),
#  ('daughter', 0.18364173741035472),
#  ('to', 0.1822949358599768),
#  ('day', 0.18019147521820322),
#  ('expensive', 0.1777070018905409),
#  ('new', 0.17436810062502683),
#  ('ride', 0.17073833257444804),
#  ('experienced', 0.17073833257444804),
#  ('quality', 0.17073833257444715),
#  ('or', 0.16401723190136952),
#  ('conrad', 0.15930963675082488),
#  ('give', 0.15766625100709497),
#  ('it', 0.15516807620264128),
#  ('say', 0.1523891939062505),
#  ('end', 0.1523891939062505),
#  ('youre', 0.1523891939062505),
#  ('bring', 0.1523891939062505),
#  ('staying', 0.15032946094324018),
#  ('around', 0.14442102425707404),
#  ('four', 0.14442102425707404),
#  ('last', 0.1379485097514559),
#  ('being', 0.1363888525598096),
#  ('first', 0.12991633805419234),
#  ('if', 0.12532512391474526),
#  ('since', 0.12421831693955543),
#  ('decided', 0.12421831693955454),
#  ('show', 0.12421831693955454),
#  ('conference', 0.1166711113041714),
#  ('for', 0.1117957969409975),
#  ('night', 0.10848901503101072),
#  ('bathroom', 0.1057335022654513),
#  ('per', 0.10359902973681834),
#  ('recent', 0.10359902973681834),
#  ('surprised', 0.10359902973681834),
#  ('much', 0.10218560193967097),
#  ('only', 0.09762886275031502),
#  ('parking', 0.09740705948889783),
#  ('getaway', 0.09523078006630215),
#  ('less', 0.09069562490091165),
#  ('tub', 0.08785067276867942),
#  ('lobby', 0.0844779882900406),
#  ('made', 0.08408621551323758),
#  ('anything', 0.08339632241929973),
#  ('know', 0.07542815277012238),
#  ('im', 0.07542815277012238),
#  ('spent', 0.07542815277012238),
#  ('immediately', 0.07542815277012238),
#  ('real', 0.07542815277012238),
#  ('site', 0.07542815277012238),
#  ('taking', 0.07542815277012238),
#  ('i', 0.07132659833196886),
#  ('extra', 0.06669447280136787),
#  ('back', 0.06323287967630442),
#  ('street', 0.05707901410192662),
#  ('kind', 0.050110344785831984),
#  ('knew', 0.050110344785831984),
#  ('level', 0.050110344785831984),
#  ('have', 0.044827712321405144),
#  ('their', 0.04033683295885204),
#  ('eggs', 0.03460615824986846),
#  ('booking', 0.03460615824986846),
#  ('property', 0.03460615824986846),
#  ('thru', 0.03460615824986846),
#  ('pretty', 0.03460615824986757),
#  ('entire', 0.03460615824986668),
#  ('could', 0.03184499680854014),
#  ('days', 0.029965778693364697),
#  ('would', 0.028034393086633358),
#  ('like', 0.026943285504298586),
#  ('service', 0.026807465764048466),
#  ('an', 0.021360931499846636),
#  ('week', 0.021360931499846636),
#  ('in', 0.020104311641461425),
#  ('looking', 0.018857801281728648),
#  ('whole', 0.016587652747189097),
#  ('job', 0.016587652747189097),
#  ('life', 0.016587652747189097),
#  ('go', 0.014127626906327073),
#  ('space', 0.006435281283170724),
#  ('than', 0.003684247911280636),
#  ('returned', -7.939973802351119e-05),
#  ('both', -0.009313075684967309),
#  ('got', -0.012540620175834682),
#  ('bed', -0.012837929528403791),
#  ('want', -0.01418400591956459),
#  ('getting', -0.01418400591956459),
#  ('our', -0.015117277102563165),
#  ('quite', -0.01850366706408124),
#  ('king', -0.01923707377095596),
#  ('my', -0.021090572306243338),
#  ('hard', -0.023890048431741917),
#  ('too', -0.023890048431741917),
#  ('experience', -0.026018463566567895),
#  ('some', -0.026276051684592794),
#  ('floor', -0.029932362887703512),
#  ('ill', -0.0299323628877044),
#  ('arrival', -0.0299323628877044),
#  ('we', -0.03414999883190717),
#  ('wanted', -0.042354882886261436),
#  ('of', -0.045854315898289144),
#  ('was', -0.047753259457814945),
#  ('by', -0.047950868390381984),
#  ('leave', -0.05240521873976256),
#  ('as', -0.05674362033836111),
#  ('the', -0.06507145815434257),
#  ('were', -0.06665436084364984),
#  ('pillow', -0.06767269087055183),
#  ('early', -0.07249197730650003),
#  ('good', -0.07872252705713567),
#  ('television', -0.07872252705713656),
#  ('longer', -0.07872252705713656),
#  ('older', -0.07872252705713656),
#  ('take', -0.09245271986903703),
#  ('used', -0.09364817727381158),
#  ('at', -0.09450913298777586),
#  ('additional', -0.09892523437465428),
#  ('based', -0.09892523437465428),
#  ('thats', -0.09892523437465606),
#  ('which', -0.10404033504142518),
#  ('next', -0.10930595042921532),
#  ('employees', -0.10997507056124078),
#  ('its', -0.1113477543732122),
#  ('high', -0.11161039390197125),
#  ('year', -0.11262407873281699),
#  ('your', -0.11694373987733364),
#  ('standard', -0.11694373987733364),
#  ('this', -0.11755133483273372),
#  ('so', -0.1215769527988213),
#  ('hotels', -0.1259754119076808),
#  ('where', -0.1311860965928764),
#  ('enough', -0.1331165991229346),
#  ('itself', -0.14771539854408733),
#  ('a', -0.15026355251224155),
#  ('different', -0.15776573439758845),
#  ('guest', -0.16713348440118825),
#  ('will', -0.16904516535042102),
#  ('time', -0.17137437286073443),
#  ('weekend', -0.17438364562624908),
#  ('again', -0.17788627617745068),
#  ('short', -0.18408304271496156),
#  ('deal', -0.18408304271496156),
#  ('makes', -0.18408304271496156),
#  ('internet', -0.18650142357924437),
#  ('travel', -0.18853739306434214),
#  ('id', -0.19027501296288296),
#  ('yes', -0.19423541417897994),
#  ('while', -0.1961677819300336),
#  ('town', -0.20178261981436307),
#  ('simply', -0.2122539196816593),
#  ('worth', -0.21833296575803995),
#  ('many', -0.22322295105223233),
#  ('you', -0.23416402931740254),
#  ('anniversary', -0.2412414565549117),
#  ('pool', -0.24249380487137628),
#  ('coffee', -0.2430255783484121),
#  ('near', -0.2443422342331587),
#  ('three', -0.24615547135733973),
#  ('with', -0.251304434553532),
#  ('each', -0.2530759142019132),
#  ('picked', -0.2530759142019132),
#  ('world', -0.2530759142019132),
#  ('member', -0.2530759142019132),
#  ('swissotel', -0.2584667628367905),
#  ('through', -0.2584667628367905),
#  ('fine', -0.26354721406920945),
#  ('few', -0.2683433863327016),
#  ('across', -0.2683433863327025),
#  ('all', -0.2704006978592197),
#  ('affinia', -0.2710944197045917),
#  ('overall', -0.2717680472140662),
#  ('must', -0.27505482092068867),
#  ('without', -0.27505482092068867),
#  ('fairmont', -0.27776852679228536),
#  ('fresh', -0.2812467911686092),
#  ('met', -0.2812467911686092),
#  ('probably', -0.2812467911686092),
#  ('treat', -0.2812467911686092),
#  ('visited', -0.2812467911686092),
#  ('bother', -0.2812467911686092),
#  ('windows', -0.2812467911686092),
#  ('st', -0.2812467911686092),
#  ('recently', -0.28457458126128454),
#  ('such', -0.2981963494823834),
#  ('just', -0.30104941846478983),
#  ('need', -0.3018660783713454),
#  ('wedding', -0.3018660783713454),
#  ('bars', -0.3018660783713454),
#  ('see', -0.30186607837134627),
#  ('and', -0.3029179815825267),
#  ('bit', -0.30864576535672406),
#  ('come', -0.3140366139916013),
#  ('romantic', -0.3176144353394843),
#  ('millennium', -0.320987119818124),
#  ('hotel', -0.3255309934173356),
#  ('ever', -0.3267636299930725),
#  ('bedroom', -0.3300369553380431),
#  ('anyone', -0.3327433169357841),
#  ('hyatt', -0.3353140124388858),
#  ('myself', -0.34008729119154246),
#  ('building', -0.34008729119154246),
#  ('son', -0.34008729119154246),
#  ('also', -0.34769189057676275),
#  ('ive', -0.3508400829678058),
#  ('bar', -0.35405183154191633),
#  ('five', -0.35535476332233173),
#  ('amenities', -0.37085894985829704),
#  ('couple', -0.37477284917943443),
#  ('regency', -0.38410417660831797),
#  ('warm', -0.38410417660831797),
#  ('nights', -0.38660730682643596),
#  ('can', -0.38844048790809715),
#  ('are', -0.3979710654767512),
#  ('wife', -0.41704833232767236),
#  ('rock', -0.41737896549319053),
#  ('accommodations', -0.4353974709958681),
#  ('during', -0.4353974709958681),
#  ('truly', -0.4353974709958681),
#  ('watch', -0.4353974709958681),
#  ('chicagos', -0.4353974709958681),
#  ('finding', -0.4353974709958681),
#  ('beer', -0.4353974709958681),
#  ('company', -0.4353974709958681),
#  ('needs', -0.4353974709958681),
#  ('drink', -0.4353974709958681),
#  ('value', -0.4353974709958681),
#  ('entrance', -0.4353974709958681),
#  ('sitting', -0.4353974709958681),
#  ('table', -0.4353974709958681),
#  ('bathrooms', -0.4353974709958681),
#  ...]
