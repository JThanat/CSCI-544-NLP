# %%
import json

# %%
with open("features.txt") as w:
    features = json.load(w)

# %%
a = set([k for k,v in features['fn']])
# Out:
# {'staying',
#  'stopped',
#  'screen',
#  'second',
#  'daughter',
#  'cut',
#  'myself',
#  'following',
#  'matter',
#  'toilet',
#  'etc',
#  'then',
#  'money',
#  'come',
#  'flat',
#  'entering',
#  'waiting',
#  'window',
#  'arguing',
#  'upon',
#  'traffic',
#  'millennium',
#  'spot',
#  'anyway',
#  'attention',
#  'ive',
#  'recommendations',
#  'frequent',
#  'called',
#  'the',
#  'walls',
#  'changed',
#  'priced',
#  'work',
#  'door',
#  'eyes',
#  'complaining',
#  'shame',
#  'condescending',
#  'everything',
#  'everywhere',
#  'acknowledge',
#  'bug',
#  'sure',
#  'missing',
#  'main',
#  'stale',
#  'beware',
#  'occupied',
#  'turns',
#  'items',
#  'definitely',
#  'speed',
#  'requests',
#  'replaced',
#  'chain',
#  'ignored',
#  'opinion',
#  'special',
#  'difficult',
#  'questions',
#  'accommodate',
#  'hardly',
#  'white',
#  'sat',
#  'color',
#  'visited',
#  'sounds',
#  'recently',
#  'policy',
#  'great',
#  'went',
#  'met',
#  'carpets',
# ...
